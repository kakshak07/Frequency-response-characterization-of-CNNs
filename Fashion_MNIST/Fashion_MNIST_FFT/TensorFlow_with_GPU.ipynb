# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import MaxPooling2D, AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# example of loading the fashion mnist dataset
from matplotlib import pyplot
from keras.datasets import fashion_mnist
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (X_train.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (X_test.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
mean_mean_fft=np.load('mean_mean_fft.npy')

# %%
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
from scipy.ndimage import gaussian_filter
io=[]


# Gaussian =gaussian_filter(X_train[i], sigma=20)
# z1=X_train[i]-Gaussian
# io.append(z1)
# io=np.array(io)
# print(io.shape)

    
    


for i in range(60000):
  X_new=np.abs(np.fft.ifft2(np.fft.fft2(X_train[i])/mean_mean_fft))
  X_new=X_new/np.max(X_new)
  z=X_new
  io.append(z)
io=np.array(io)
print(io.shape)
op=[]
for j in range(10000):
  X_new=np.abs(np.fft.ifft2(np.fft.fft2(X_test[j])/mean_mean_fft))
  X_new=X_new/np.max(X_new)
  z1=X_new
  op.append(z1)
op=np.array(op)
print(op.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
#Summary after Gaussian filter
print('Train: X=%s, y=%s' % (io.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (op.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(io[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
#Defining constants
epochs = 200
batch_size = 100
data_augmentation = False
img_size = 28

num_classes = 10
num_filters = 64
num_blocks = 4
num_sub_blocks = 2
use_max_pool = False

# %%
x_train = io.reshape(io.shape[0],img_size,img_size,1)
x_test = op.reshape(op.shape[0],img_size,img_size,1)
input_size = (img_size, img_size,1)
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('Y_train shape:', Y_train.shape)

#Converting labels to one-hot vectors
y_train = keras.utils.to_categorical(Y_train, num_classes)
y_test = keras.utils.to_categorical(Y_test,num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Y_train shape: (60000,)

# %%
#Creating model based on ResNet published archietecture
inputs = Input(shape=input_size)
x = Conv2D(num_filters, padding='same', 
           kernel_initializer='he_normal', 
           kernel_size=7, strides=2,
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

#Check by applying max pooling later (setting it false as size of image is small i.e. 28x28)
if use_max_pool:
    x = MaxPooling2D(pool_size=3,padding='same', strides=2)(x)
    num_blocks =3
#Creating Conv base stack 

# Instantiate convolutional base (stack of blocks).
for i in range(num_blocks):
    for j in range(num_sub_blocks):
        strides = 1
        is_first_layer_but_not_first_block = j == 0 and i > 0
        if is_first_layer_but_not_first_block:
            strides = 2
        #Creating residual mapping using y
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   strides=strides,
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if is_first_layer_but_not_first_block:
            x = Conv2D(num_filters,
                       kernel_size=1,
                       padding='same',
                       strides=2,
                       kernel_initializer='he_normal',
                       kernel_regularizer=l2(1e-4))(x)
        #Adding back residual mapping
        x = keras.layers.add([x, y])
        x = Activation('relu')(x)

    num_filters = 2 * num_filters

# Add classifier on top.
x = AveragePooling2D()(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                activation='softmax',
                kernel_initializer='he_normal')(y)

# Instantiate and compile model.
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 14, 14, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 14, 14, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 64)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 64)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 128)    8320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 7, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 128)    0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 128)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 128)    0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 256)    295168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 256)    33024       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 256)    0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 512)    1180160     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 512)    131584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 512)    0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 512)    0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 512)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,186,186
# Trainable params: 11,178,378
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'saved_model')
model_name = 'fmnist_resnet20_Original_Image_fft.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir,model_name)
print(filepath)
# Prepare callbacks for model saving and for learning rate decaying.
checkpoint = ModelCheckpoint(filepath=filepath,
                             verbose=1,
                             save_best_only=True)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer]
# Out:
# /content/saved_model/fmnist_resnet20_Original_Image_fft.h5

# %%
if not data_augmentation:
    print('Using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
# Out:
# Using data augmentation.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 108s 2ms/step - loss: 1.3216 - accuracy: 0.8159 - val_loss: 3.0691 - val_accuracy: 0.2509
#
# Epoch 00001: val_loss improved from inf to 3.06912, saving model to /content/saved_model/fmnist_resnet20_Original_Image_fft.h5
# Epoch 2/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.8632 - accuracy: 0.8719 - val_loss: 23.8919 - val_accuracy: 0.1115
#
# Epoch 00002: val_loss did not improve from 3.06912
# Epoch 3/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.6867 - accuracy: 0.8875 - val_loss: 6.2987 - val_accuracy: 0.2366
#
# Epoch 00003: val_loss did not improve from 3.06912
# Epoch 4/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.5942 - accuracy: 0.8976 - val_loss: 5.4632 - val_accuracy: 0.1241
#
# Epoch 00004: val_loss did not improve from 3.06912
# Epoch 5/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.5378 - accuracy: 0.9060 - val_loss: 5.6651 - val_accuracy: 0.1498
#
# Epoch 00005: val_loss did not improve from 3.06912
# Epoch 6/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.5005 - accuracy: 0.9132 - val_loss: 22.6642 - val_accuracy: 0.1676
#
# Epoch 00006: val_loss did not improve from 3.06912
# Epoch 7/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.3628 - accuracy: 0.9558 - val_loss: 3.1729 - val_accuracy: 0.2504
#
# Epoch 00007: val_loss did not improve from 3.06912
# Epoch 8/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.2929 - accuracy: 0.9737 - val_loss: 3.1568 - val_accuracy: 0.3073
#
# Epoch 00008: val_loss did not improve from 3.06912
# Epoch 9/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2611 - accuracy: 0.9813 - val_loss: 5.6830 - val_accuracy: 0.1992
#
# Epoch 00009: val_loss did not improve from 3.06912
# Epoch 10/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.2474 - accuracy: 0.9836 - val_loss: 4.4633 - val_accuracy: 0.1418
#
# Epoch 00010: val_loss did not improve from 3.06912
# Epoch 11/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.2322 - accuracy: 0.9867 - val_loss: 4.9612 - val_accuracy: 0.1454
#
# Epoch 00011: val_loss did not improve from 3.06912
# Epoch 12/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1954 - accuracy: 0.9975 - val_loss: 0.8855 - val_accuracy: 0.8539
#
# Epoch 00012: val_loss improved from 3.06912 to 0.88548, saving model to /content/saved_model/fmnist_resnet20_Original_Image_fft.h5
# Epoch 13/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1794 - accuracy: 0.9999 - val_loss: 0.8928 - val_accuracy: 0.8846
#
# Epoch 00013: val_loss did not improve from 0.88548
# Epoch 14/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1715 - accuracy: 0.9995 - val_loss: 1.4268 - val_accuracy: 0.7451
#
# Epoch 00014: val_loss did not improve from 0.88548
# Epoch 15/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1657 - accuracy: 0.9989 - val_loss: 3.7417 - val_accuracy: 0.4605
#
# Epoch 00015: val_loss did not improve from 0.88548
# Epoch 16/200
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.1609 - accuracy: 0.9984 - val_loss: 2.8489 - val_accuracy: 0.4912
#
# Epoch 00016: val_loss did not improve from 0.88548
# Epoch 17/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1542 - accuracy: 0.9986 - val_loss: 2.2597 - val_accuracy: 0.6291
#
# Epoch 00017: val_loss did not improve from 0.88548
# Epoch 18/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1471 - accuracy: 0.9998 - val_loss: 0.9410 - val_accuracy: 0.8810
#
# Epoch 00018: val_loss did not improve from 0.88548
# Epoch 19/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1432 - accuracy: 1.0000 - val_loss: 1.0137 - val_accuracy: 0.8826
#
# Epoch 00019: val_loss did not improve from 0.88548
# Epoch 20/200
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.1395 - accuracy: 1.0000 - val_loss: 1.0917 - val_accuracy: 0.8819
#
# Epoch 00020: val_loss did not improve from 0.88548
# Epoch 21/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1362 - accuracy: 0.9999 - val_loss: 0.9754 - val_accuracy: 0.8808
#
# Epoch 00021: val_loss did not improve from 0.88548
# Epoch 22/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1322 - accuracy: 0.9998 - val_loss: 1.0291 - val_accuracy: 0.8766
#
# Epoch 00022: val_loss did not improve from 0.88548
# Epoch 23/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1291 - accuracy: 0.9999 - val_loss: 1.0188 - val_accuracy: 0.8835
#
# Epoch 00023: val_loss did not improve from 0.88548
# Epoch 24/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1272 - accuracy: 1.0000 - val_loss: 1.0969 - val_accuracy: 0.8834
#
# Epoch 00024: val_loss did not improve from 0.88548
# Epoch 25/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1252 - accuracy: 1.0000 - val_loss: 1.1523 - val_accuracy: 0.8836
#
# Epoch 00025: val_loss did not improve from 0.88548
# Epoch 26/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1226 - accuracy: 1.0000 - val_loss: 1.2023 - val_accuracy: 0.8823
#
# Epoch 00026: val_loss did not improve from 0.88548
# Epoch 27/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1198 - accuracy: 1.0000 - val_loss: 1.0888 - val_accuracy: 0.8829
#
# Epoch 00027: val_loss did not improve from 0.88548
# Epoch 28/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1179 - accuracy: 1.0000 - val_loss: 1.1508 - val_accuracy: 0.8836
#
# Epoch 00028: val_loss did not improve from 0.88548
# Epoch 29/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1168 - accuracy: 1.0000 - val_loss: 1.2009 - val_accuracy: 0.8834
#
# Epoch 00029: val_loss did not improve from 0.88548
# Epoch 30/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1154 - accuracy: 1.0000 - val_loss: 1.2437 - val_accuracy: 0.8830
#
# Epoch 00030: val_loss did not improve from 0.88548
# Epoch 31/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1136 - accuracy: 1.0000 - val_loss: 1.2887 - val_accuracy: 0.8838
#
# Epoch 00031: val_loss did not improve from 0.88548
# Epoch 32/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1116 - accuracy: 1.0000 - val_loss: 1.3140 - val_accuracy: 0.8827
#
# Epoch 00032: val_loss did not improve from 0.88548
# Epoch 33/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1101 - accuracy: 1.0000 - val_loss: 1.3385 - val_accuracy: 0.8829
#
# Epoch 00033: val_loss did not improve from 0.88548
# Epoch 34/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1095 - accuracy: 1.0000 - val_loss: 1.3489 - val_accuracy: 0.8825
#
# Epoch 00034: val_loss did not improve from 0.88548
# Epoch 35/200
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.1087 - accuracy: 1.0000 - val_loss: 1.3650 - val_accuracy: 0.8829
#
# Epoch 00035: val_loss did not improve from 0.88548
# Epoch 36/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1079 - accuracy: 1.0000 - val_loss: 1.3813 - val_accuracy: 0.8827
#
# Epoch 00036: val_loss did not improve from 0.88548
# Epoch 37/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1070 - accuracy: 1.0000 - val_loss: 1.3872 - val_accuracy: 0.8828
#
# Epoch 00037: val_loss did not improve from 0.88548
# Epoch 38/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1063 - accuracy: 1.0000 - val_loss: 1.3993 - val_accuracy: 0.8835
#
# Epoch 00038: val_loss did not improve from 0.88548
# Epoch 39/200
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.1057 - accuracy: 1.0000 - val_loss: 1.4010 - val_accuracy: 0.8833
#
# Epoch 00039: val_loss did not improve from 0.88548
# Epoch 40/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1051 - accuracy: 1.0000 - val_loss: 1.4069 - val_accuracy: 0.8831
#
# Epoch 00040: val_loss did not improve from 0.88548
# Epoch 41/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1047 - accuracy: 1.0000 - val_loss: 1.4114 - val_accuracy: 0.8823
#
# Epoch 00041: val_loss did not improve from 0.88548
# Epoch 42/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1043 - accuracy: 1.0000 - val_loss: 1.4100 - val_accuracy: 0.8835
#
# Epoch 00042: val_loss did not improve from 0.88548
# Epoch 43/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1038 - accuracy: 1.0000 - val_loss: 1.4121 - val_accuracy: 0.8828
#
# Epoch 00043: val_loss did not improve from 0.88548
# Epoch 44/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1034 - accuracy: 1.0000 - val_loss: 1.4115 - val_accuracy: 0.8829
#
# Epoch 00044: val_loss did not improve from 0.88548
# Epoch 45/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1030 - accuracy: 1.0000 - val_loss: 1.4134 - val_accuracy: 0.8823
#
# Epoch 00045: val_loss did not improve from 0.88548
# Epoch 46/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1028 - accuracy: 1.0000 - val_loss: 1.4151 - val_accuracy: 0.8827
#
# Epoch 00046: val_loss did not improve from 0.88548
# Epoch 47/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1025 - accuracy: 1.0000 - val_loss: 1.4210 - val_accuracy: 0.8828
#
# Epoch 00047: val_loss did not improve from 0.88548
# Epoch 48/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1022 - accuracy: 1.0000 - val_loss: 1.4214 - val_accuracy: 0.8828
#
# Epoch 00048: val_loss did not improve from 0.88548
# Epoch 49/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1019 - accuracy: 1.0000 - val_loss: 1.4230 - val_accuracy: 0.8823
#
# Epoch 00049: val_loss did not improve from 0.88548
# Epoch 50/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1015 - accuracy: 1.0000 - val_loss: 1.4269 - val_accuracy: 0.8827
#
# Epoch 00050: val_loss did not improve from 0.88548
# Epoch 51/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.1010 - accuracy: 1.0000 - val_loss: 1.4290 - val_accuracy: 0.8839
#
# Epoch 00051: val_loss did not improve from 0.88548
# Epoch 52/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.1005 - accuracy: 1.0000 - val_loss: 1.4374 - val_accuracy: 0.8834
#
# Epoch 00052: val_loss did not improve from 0.88548
# Epoch 53/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0999 - accuracy: 1.0000 - val_loss: 1.4396 - val_accuracy: 0.8836
#
# Epoch 00053: val_loss did not improve from 0.88548
# Epoch 54/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0992 - accuracy: 1.0000 - val_loss: 1.4515 - val_accuracy: 0.8831
#
# Epoch 00054: val_loss did not improve from 0.88548
# Epoch 55/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0985 - accuracy: 1.0000 - val_loss: 1.4586 - val_accuracy: 0.8833
#
# Epoch 00055: val_loss did not improve from 0.88548
# Epoch 56/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0977 - accuracy: 1.0000 - val_loss: 1.4713 - val_accuracy: 0.8830
#
# Epoch 00056: val_loss did not improve from 0.88548
# Epoch 57/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 1.4859 - val_accuracy: 0.8822
#
# Epoch 00057: val_loss did not improve from 0.88548
# Epoch 58/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 1.4864 - val_accuracy: 0.8833
#
# Epoch 00058: val_loss did not improve from 0.88548
# Epoch 59/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 1.4907 - val_accuracy: 0.8831
#
# Epoch 00059: val_loss did not improve from 0.88548
# Epoch 60/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0955 - accuracy: 1.0000 - val_loss: 1.4902 - val_accuracy: 0.8835
#
# Epoch 00060: val_loss did not improve from 0.88548
# Epoch 61/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0952 - accuracy: 1.0000 - val_loss: 1.4868 - val_accuracy: 0.8834
#
# Epoch 00061: val_loss did not improve from 0.88548
# Epoch 62/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0950 - accuracy: 1.0000 - val_loss: 1.4844 - val_accuracy: 0.8833
#
# Epoch 00062: val_loss did not improve from 0.88548
# Epoch 63/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0947 - accuracy: 1.0000 - val_loss: 1.4796 - val_accuracy: 0.8837
#
# Epoch 00063: val_loss did not improve from 0.88548
# Epoch 64/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0945 - accuracy: 1.0000 - val_loss: 1.4764 - val_accuracy: 0.8833
#
# Epoch 00064: val_loss did not improve from 0.88548
# Epoch 65/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0942 - accuracy: 1.0000 - val_loss: 1.4859 - val_accuracy: 0.8836
#
# Epoch 00065: val_loss did not improve from 0.88548
# Epoch 66/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0940 - accuracy: 1.0000 - val_loss: 1.4880 - val_accuracy: 0.8828
#
# Epoch 00066: val_loss did not improve from 0.88548
# Epoch 67/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 1.4874 - val_accuracy: 0.8826
#
# Epoch 00067: val_loss did not improve from 0.88548
# Epoch 68/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0932 - accuracy: 1.0000 - val_loss: 1.4901 - val_accuracy: 0.8827
#
# Epoch 00068: val_loss did not improve from 0.88548
# Epoch 69/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 1.4880 - val_accuracy: 0.8826
#
# Epoch 00069: val_loss did not improve from 0.88548
# Epoch 70/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0922 - accuracy: 1.0000 - val_loss: 1.4894 - val_accuracy: 0.8830
#
# Epoch 00070: val_loss did not improve from 0.88548
# Epoch 71/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0916 - accuracy: 1.0000 - val_loss: 1.4797 - val_accuracy: 0.8829
#
# Epoch 00071: val_loss did not improve from 0.88548
# Epoch 72/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0911 - accuracy: 1.0000 - val_loss: 1.4845 - val_accuracy: 0.8831
#
# Epoch 00072: val_loss did not improve from 0.88548
# Epoch 73/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0905 - accuracy: 1.0000 - val_loss: 1.4800 - val_accuracy: 0.8830
#
# Epoch 00073: val_loss did not improve from 0.88548
# Epoch 74/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0899 - accuracy: 1.0000 - val_loss: 1.4931 - val_accuracy: 0.8832
#
# Epoch 00074: val_loss did not improve from 0.88548
# Epoch 75/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0894 - accuracy: 1.0000 - val_loss: 1.4967 - val_accuracy: 0.8831
#
# Epoch 00075: val_loss did not improve from 0.88548
# Epoch 76/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0890 - accuracy: 1.0000 - val_loss: 1.4982 - val_accuracy: 0.8825
#
# Epoch 00076: val_loss did not improve from 0.88548
# Epoch 77/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 1.4962 - val_accuracy: 0.8828
#
# Epoch 00077: val_loss did not improve from 0.88548
# Epoch 78/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0884 - accuracy: 1.0000 - val_loss: 1.4870 - val_accuracy: 0.8821
#
# Epoch 00078: val_loss did not improve from 0.88548
# Epoch 79/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0881 - accuracy: 1.0000 - val_loss: 1.5004 - val_accuracy: 0.8822
#
# Epoch 00079: val_loss did not improve from 0.88548
# Epoch 80/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0878 - accuracy: 1.0000 - val_loss: 1.4964 - val_accuracy: 0.8828
#
# Epoch 00080: val_loss did not improve from 0.88548
# Epoch 81/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 1.4964 - val_accuracy: 0.8827
#
# Epoch 00081: val_loss did not improve from 0.88548
# Epoch 82/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0869 - accuracy: 1.0000 - val_loss: 1.4933 - val_accuracy: 0.8827
#
# Epoch 00082: val_loss did not improve from 0.88548
# Epoch 83/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0865 - accuracy: 1.0000 - val_loss: 1.4974 - val_accuracy: 0.8834
#
# Epoch 00083: val_loss did not improve from 0.88548
# Epoch 84/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0863 - accuracy: 1.0000 - val_loss: 1.4921 - val_accuracy: 0.8833
#
# Epoch 00084: val_loss did not improve from 0.88548
# Epoch 85/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0861 - accuracy: 1.0000 - val_loss: 1.4980 - val_accuracy: 0.8831
#
# Epoch 00085: val_loss did not improve from 0.88548
# Epoch 86/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0858 - accuracy: 1.0000 - val_loss: 1.4953 - val_accuracy: 0.8831
#
# Epoch 00086: val_loss did not improve from 0.88548
# Epoch 87/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0854 - accuracy: 1.0000 - val_loss: 1.5021 - val_accuracy: 0.8839
#
# Epoch 00087: val_loss did not improve from 0.88548
# Epoch 88/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0851 - accuracy: 1.0000 - val_loss: 1.4895 - val_accuracy: 0.8844
#
# Epoch 00088: val_loss did not improve from 0.88548
# Epoch 89/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0849 - accuracy: 1.0000 - val_loss: 1.4929 - val_accuracy: 0.8823
#
# Epoch 00089: val_loss did not improve from 0.88548
# Epoch 90/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 1.4931 - val_accuracy: 0.8828
#
# Epoch 00090: val_loss did not improve from 0.88548
# Epoch 91/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0844 - accuracy: 1.0000 - val_loss: 1.4819 - val_accuracy: 0.8834
#
# Epoch 00091: val_loss did not improve from 0.88548
# Epoch 92/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0843 - accuracy: 1.0000 - val_loss: 1.4889 - val_accuracy: 0.8829
#
# Epoch 00092: val_loss did not improve from 0.88548
# Epoch 93/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0842 - accuracy: 1.0000 - val_loss: 1.4843 - val_accuracy: 0.8833
#
# Epoch 00093: val_loss did not improve from 0.88548
# Epoch 94/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0840 - accuracy: 1.0000 - val_loss: 1.4872 - val_accuracy: 0.8839
#
# Epoch 00094: val_loss did not improve from 0.88548
# Epoch 95/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 1.4849 - val_accuracy: 0.8833
#
# Epoch 00095: val_loss did not improve from 0.88548
# Epoch 96/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0835 - accuracy: 1.0000 - val_loss: 1.4875 - val_accuracy: 0.8838
#
# Epoch 00096: val_loss did not improve from 0.88548
# Epoch 97/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 1.4861 - val_accuracy: 0.8847
#
# Epoch 00097: val_loss did not improve from 0.88548
# Epoch 98/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0831 - accuracy: 1.0000 - val_loss: 1.4793 - val_accuracy: 0.8838
#
# Epoch 00098: val_loss did not improve from 0.88548
# Epoch 99/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0830 - accuracy: 1.0000 - val_loss: 1.4793 - val_accuracy: 0.8833
#
# Epoch 00099: val_loss did not improve from 0.88548
# Epoch 100/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0829 - accuracy: 1.0000 - val_loss: 1.4784 - val_accuracy: 0.8839
#
# Epoch 00100: val_loss did not improve from 0.88548
# Epoch 101/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 1.4784 - val_accuracy: 0.8824
#
# Epoch 00101: val_loss did not improve from 0.88548
# Epoch 102/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0827 - accuracy: 1.0000 - val_loss: 1.4712 - val_accuracy: 0.8830
#
# Epoch 00102: val_loss did not improve from 0.88548
# Epoch 103/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 1.4689 - val_accuracy: 0.8833
#
# Epoch 00103: val_loss did not improve from 0.88548
# Epoch 104/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 1.4732 - val_accuracy: 0.8831
#
# Epoch 00104: val_loss did not improve from 0.88548
# Epoch 105/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0823 - accuracy: 1.0000 - val_loss: 1.4805 - val_accuracy: 0.8825
#
# Epoch 00105: val_loss did not improve from 0.88548
# Epoch 106/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0821 - accuracy: 1.0000 - val_loss: 1.4737 - val_accuracy: 0.8836
#
# Epoch 00106: val_loss did not improve from 0.88548
# Epoch 107/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 1.4779 - val_accuracy: 0.8831
#
# Epoch 00107: val_loss did not improve from 0.88548
# Epoch 108/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 1.4728 - val_accuracy: 0.8826
#
# Epoch 00108: val_loss did not improve from 0.88548
# Epoch 109/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.4614 - val_accuracy: 0.8830
#
# Epoch 00109: val_loss did not improve from 0.88548
# Epoch 110/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 1.4732 - val_accuracy: 0.8830
#
# Epoch 00110: val_loss did not improve from 0.88548
# Epoch 111/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 1.4779 - val_accuracy: 0.8835
#
# Epoch 00111: val_loss did not improve from 0.88548
# Epoch 112/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 1.4761 - val_accuracy: 0.8835
#
# Epoch 00112: val_loss did not improve from 0.88548
# Epoch 113/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0810 - accuracy: 1.0000 - val_loss: 1.4696 - val_accuracy: 0.8837
#
# Epoch 00113: val_loss did not improve from 0.88548
# Epoch 114/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0809 - accuracy: 1.0000 - val_loss: 1.4698 - val_accuracy: 0.8832
#
# Epoch 00114: val_loss did not improve from 0.88548
# Epoch 115/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 1.4618 - val_accuracy: 0.8833
#
# Epoch 00115: val_loss did not improve from 0.88548
# Epoch 116/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 1.4654 - val_accuracy: 0.8834
#
# Epoch 00116: val_loss did not improve from 0.88548
# Epoch 117/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0805 - accuracy: 1.0000 - val_loss: 1.4597 - val_accuracy: 0.8835
#
# Epoch 00117: val_loss did not improve from 0.88548
# Epoch 118/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0804 - accuracy: 1.0000 - val_loss: 1.4661 - val_accuracy: 0.8821
#
# Epoch 00118: val_loss did not improve from 0.88548
# Epoch 119/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0803 - accuracy: 1.0000 - val_loss: 1.4663 - val_accuracy: 0.8835
#
# Epoch 00119: val_loss did not improve from 0.88548
# Epoch 120/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0802 - accuracy: 1.0000 - val_loss: 1.4706 - val_accuracy: 0.8832
#
# Epoch 00120: val_loss did not improve from 0.88548
# Epoch 121/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0801 - accuracy: 1.0000 - val_loss: 1.4700 - val_accuracy: 0.8828
#
# Epoch 00121: val_loss did not improve from 0.88548
# Epoch 122/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0800 - accuracy: 1.0000 - val_loss: 1.4700 - val_accuracy: 0.8827
#
# Epoch 00122: val_loss did not improve from 0.88548
# Epoch 123/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 1.4676 - val_accuracy: 0.8830
#
# Epoch 00123: val_loss did not improve from 0.88548
# Epoch 124/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 1.4789 - val_accuracy: 0.8820
#
# Epoch 00124: val_loss did not improve from 0.88548
# Epoch 125/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0796 - accuracy: 1.0000 - val_loss: 1.4741 - val_accuracy: 0.8820
#
# Epoch 00125: val_loss did not improve from 0.88548
# Epoch 126/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 1.4699 - val_accuracy: 0.8819
#
# Epoch 00126: val_loss did not improve from 0.88548
# Epoch 127/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 1.4625 - val_accuracy: 0.8825
#
# Epoch 00127: val_loss did not improve from 0.88548
# Epoch 128/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 1.4639 - val_accuracy: 0.8830
#
# Epoch 00128: val_loss did not improve from 0.88548
# Epoch 129/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0789 - accuracy: 1.0000 - val_loss: 1.4662 - val_accuracy: 0.8823
#
# Epoch 00129: val_loss did not improve from 0.88548
# Epoch 130/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0788 - accuracy: 1.0000 - val_loss: 1.4661 - val_accuracy: 0.8831
#
# Epoch 00130: val_loss did not improve from 0.88548
# Epoch 131/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 1.4666 - val_accuracy: 0.8830
#
# Epoch 00131: val_loss did not improve from 0.88548
# Epoch 132/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0785 - accuracy: 1.0000 - val_loss: 1.4663 - val_accuracy: 0.8825
#
# Epoch 00132: val_loss did not improve from 0.88548
# Epoch 133/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0783 - accuracy: 1.0000 - val_loss: 1.4681 - val_accuracy: 0.8824
#
# Epoch 00133: val_loss did not improve from 0.88548
# Epoch 134/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0781 - accuracy: 1.0000 - val_loss: 1.4675 - val_accuracy: 0.8826
#
# Epoch 00134: val_loss did not improve from 0.88548
# Epoch 135/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 1.4775 - val_accuracy: 0.8821
#
# Epoch 00135: val_loss did not improve from 0.88548
# Epoch 136/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 1.4610 - val_accuracy: 0.8816
#
# Epoch 00136: val_loss did not improve from 0.88548
# Epoch 137/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 1.4667 - val_accuracy: 0.8819
#
# Epoch 00137: val_loss did not improve from 0.88548
# Epoch 138/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 1.4780 - val_accuracy: 0.8826
#
# Epoch 00138: val_loss did not improve from 0.88548
# Epoch 139/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 1.4813 - val_accuracy: 0.8824
#
# Epoch 00139: val_loss did not improve from 0.88548
# Epoch 140/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0768 - accuracy: 1.0000 - val_loss: 1.4733 - val_accuracy: 0.8837
#
# Epoch 00140: val_loss did not improve from 0.88548
# Epoch 141/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0766 - accuracy: 1.0000 - val_loss: 1.4701 - val_accuracy: 0.8833
#
# Epoch 00141: val_loss did not improve from 0.88548
# Epoch 142/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0763 - accuracy: 1.0000 - val_loss: 1.4751 - val_accuracy: 0.8834
#
# Epoch 00142: val_loss did not improve from 0.88548
# Epoch 143/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0760 - accuracy: 1.0000 - val_loss: 1.4791 - val_accuracy: 0.8826
#
# Epoch 00143: val_loss did not improve from 0.88548
# Epoch 144/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 1.4704 - val_accuracy: 0.8833
#
# Epoch 00144: val_loss did not improve from 0.88548
# Epoch 145/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 1.4783 - val_accuracy: 0.8833
#
# Epoch 00145: val_loss did not improve from 0.88548
# Epoch 146/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0751 - accuracy: 1.0000 - val_loss: 1.4833 - val_accuracy: 0.8827
#
# Epoch 00146: val_loss did not improve from 0.88548
# Epoch 147/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 1.4815 - val_accuracy: 0.8823
#
# Epoch 00147: val_loss did not improve from 0.88548
# Epoch 148/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 1.4855 - val_accuracy: 0.8827
#
# Epoch 00148: val_loss did not improve from 0.88548
# Epoch 149/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 1.4744 - val_accuracy: 0.8820
#
# Epoch 00149: val_loss did not improve from 0.88548
# Epoch 150/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 1.4642 - val_accuracy: 0.8835
#
# Epoch 00150: val_loss did not improve from 0.88548
# Epoch 151/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0745 - accuracy: 1.0000 - val_loss: 1.4640 - val_accuracy: 0.8829
#
# Epoch 00151: val_loss did not improve from 0.88548
# Epoch 152/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0744 - accuracy: 1.0000 - val_loss: 1.4701 - val_accuracy: 0.8825
#
# Epoch 00152: val_loss did not improve from 0.88548
# Epoch 153/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0742 - accuracy: 1.0000 - val_loss: 1.4723 - val_accuracy: 0.8831
#
# Epoch 00153: val_loss did not improve from 0.88548
# Epoch 154/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 1.4715 - val_accuracy: 0.8829
#
# Epoch 00154: val_loss did not improve from 0.88548
# Epoch 155/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 1.4833 - val_accuracy: 0.8825
#
# Epoch 00155: val_loss did not improve from 0.88548
# Epoch 156/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 1.4712 - val_accuracy: 0.8830
#
# Epoch 00156: val_loss did not improve from 0.88548
# Epoch 157/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 1.4692 - val_accuracy: 0.8828
#
# Epoch 00157: val_loss did not improve from 0.88548
# Epoch 158/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0737 - accuracy: 1.0000 - val_loss: 1.4663 - val_accuracy: 0.8822
#
# Epoch 00158: val_loss did not improve from 0.88548
# Epoch 159/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 1.4585 - val_accuracy: 0.8823
#
# Epoch 00159: val_loss did not improve from 0.88548
# Epoch 160/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 1.4682 - val_accuracy: 0.8823
#
# Epoch 00160: val_loss did not improve from 0.88548
# Epoch 161/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 1.4646 - val_accuracy: 0.8817
#
# Epoch 00161: val_loss did not improve from 0.88548
# Epoch 162/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 1.4697 - val_accuracy: 0.8829
#
# Epoch 00162: val_loss did not improve from 0.88548
# Epoch 163/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 1.4626 - val_accuracy: 0.8831
#
# Epoch 00163: val_loss did not improve from 0.88548
# Epoch 164/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 1.4614 - val_accuracy: 0.8831
#
# Epoch 00164: val_loss did not improve from 0.88548
# Epoch 165/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0722 - accuracy: 1.0000 - val_loss: 1.4648 - val_accuracy: 0.8831
#
# Epoch 00165: val_loss did not improve from 0.88548
# Epoch 166/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0718 - accuracy: 1.0000 - val_loss: 1.4579 - val_accuracy: 0.8824
#
# Epoch 00166: val_loss did not improve from 0.88548
# Epoch 167/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 1.4539 - val_accuracy: 0.8824
#
# Epoch 00167: val_loss did not improve from 0.88548
# Epoch 168/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 1.4546 - val_accuracy: 0.8834
#
# Epoch 00168: val_loss did not improve from 0.88548
# Epoch 169/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 1.4563 - val_accuracy: 0.8823
#
# Epoch 00169: val_loss did not improve from 0.88548
# Epoch 170/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 1.4586 - val_accuracy: 0.8827
#
# Epoch 00170: val_loss did not improve from 0.88548
# Epoch 171/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 1.4602 - val_accuracy: 0.8827
#
# Epoch 00171: val_loss did not improve from 0.88548
# Epoch 172/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0710 - accuracy: 1.0000 - val_loss: 1.4571 - val_accuracy: 0.8833
#
# Epoch 00172: val_loss did not improve from 0.88548
# Epoch 173/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0708 - accuracy: 1.0000 - val_loss: 1.4562 - val_accuracy: 0.8835
#
# Epoch 00173: val_loss did not improve from 0.88548
# Epoch 174/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0707 - accuracy: 1.0000 - val_loss: 1.4648 - val_accuracy: 0.8824
#
# Epoch 00174: val_loss did not improve from 0.88548
# Epoch 175/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0705 - accuracy: 1.0000 - val_loss: 1.4686 - val_accuracy: 0.8829
#
# Epoch 00175: val_loss did not improve from 0.88548
# Epoch 176/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 1.4609 - val_accuracy: 0.8837
#
# Epoch 00176: val_loss did not improve from 0.88548
# Epoch 177/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0703 - accuracy: 1.0000 - val_loss: 1.4703 - val_accuracy: 0.8831
#
# Epoch 00177: val_loss did not improve from 0.88548
# Epoch 178/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0702 - accuracy: 1.0000 - val_loss: 1.4623 - val_accuracy: 0.8831
#
# Epoch 00178: val_loss did not improve from 0.88548
# Epoch 179/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 1.4670 - val_accuracy: 0.8821
#
# Epoch 00179: val_loss did not improve from 0.88548
# Epoch 180/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0700 - accuracy: 1.0000 - val_loss: 1.4718 - val_accuracy: 0.8818
#
# Epoch 00180: val_loss did not improve from 0.88548
# Epoch 181/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 1.4597 - val_accuracy: 0.8829
#
# Epoch 00181: val_loss did not improve from 0.88548
# Epoch 182/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 1.4549 - val_accuracy: 0.8818
#
# Epoch 00182: val_loss did not improve from 0.88548
# Epoch 183/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 1.4486 - val_accuracy: 0.8823
#
# Epoch 00183: val_loss did not improve from 0.88548
# Epoch 184/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0697 - accuracy: 1.0000 - val_loss: 1.4527 - val_accuracy: 0.8822
#
# Epoch 00184: val_loss did not improve from 0.88548
# Epoch 185/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 1.4531 - val_accuracy: 0.8817
#
# Epoch 00185: val_loss did not improve from 0.88548
# Epoch 186/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0694 - accuracy: 1.0000 - val_loss: 1.4682 - val_accuracy: 0.8820
#
# Epoch 00186: val_loss did not improve from 0.88548
# Epoch 187/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 1.4641 - val_accuracy: 0.8816
#
# Epoch 00187: val_loss did not improve from 0.88548
# Epoch 188/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 1.4717 - val_accuracy: 0.8807
#
# Epoch 00188: val_loss did not improve from 0.88548
# Epoch 189/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 1.4673 - val_accuracy: 0.8820
#
# Epoch 00189: val_loss did not improve from 0.88548
# Epoch 190/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 1.4695 - val_accuracy: 0.8825
#
# Epoch 00190: val_loss did not improve from 0.88548
# Epoch 191/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 1.4630 - val_accuracy: 0.8828
#
# Epoch 00191: val_loss did not improve from 0.88548
# Epoch 192/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 1.4650 - val_accuracy: 0.8829
#
# Epoch 00192: val_loss did not improve from 0.88548
# Epoch 193/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 1.4646 - val_accuracy: 0.8827
#
# Epoch 00193: val_loss did not improve from 0.88548
# Epoch 194/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 1.4538 - val_accuracy: 0.8828
#
# Epoch 00194: val_loss did not improve from 0.88548
# Epoch 195/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0685 - accuracy: 1.0000 - val_loss: 1.4539 - val_accuracy: 0.8821
#
# Epoch 00195: val_loss did not improve from 0.88548
# Epoch 196/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 1.4471 - val_accuracy: 0.8831
#
# Epoch 00196: val_loss did not improve from 0.88548
# Epoch 197/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 1.4483 - val_accuracy: 0.8838
#
# Epoch 00197: val_loss did not improve from 0.88548
# Epoch 198/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0683 - accuracy: 1.0000 - val_loss: 1.4584 - val_accuracy: 0.8830
#
# Epoch 00198: val_loss did not improve from 0.88548
# Epoch 199/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 0.0682 - accuracy: 1.0000 - val_loss: 1.4565 - val_accuracy: 0.8833
#
# Epoch 00199: val_loss did not improve from 0.88548
# Epoch 200/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 0.0681 - accuracy: 1.0000 - val_loss: 1.4545 - val_accuracy: 0.8838
#
# Epoch 00200: val_loss did not improve from 0.88548

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 8s 790us/step
# Test loss: 1.454487647151947
# Test accuracy: 0.8838000297546387

# %%
model.save("fmnist_resnet20_Original_Image_fft.h5")

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# Iterate over layers
plot_filt=0
n_pad=15
layer_counter=0
for layer in model.layers:
	  # check for convolutional layer
    if 'conv' in layer.name:
        # if filters are 3x3 or larger:
        if layer.kernel.shape[0]>=3 and layer.kernel.shape[1]>=3:
            layer_counter+=1
            list_f_response=np.zeros(layer.kernel.shape[-2]*layer.kernel.shape[-1])
            # summarize kernel shape
            print(layer_counter,layer.name,layer.kernel.shape)
            filter_counter=0
            # Iterate over every 3x3 filter in this layer
            for in_ch in range(layer.kernel.shape[-2]):
                for out_ch in range(layer.kernel.shape[-1]):
                    # pad and fft the filters
                    p_filter=layer.kernel[:,:,in_ch,out_ch]
                    filter_pad=np.pad(p_filter,pad_width=n_pad,mode='constant',constant_values=0)
                    filter_fft=np.fft.fftshift(np.abs(np.fft.fft2(filter_pad))**2)
                    filter_fft=filter_fft/np.sum(filter_fft)
                    # plot some fft examples
                    if filter_counter<plot_filt:
                        plt.imshow(filter_fft)
                        plt.colorbar()
                        plt.pause(1)
                    
                    # get x and y axis to quantify HP/LP structure
                    f_axis_0=np.arange(filter_fft.shape[0])
                    f_axis_0[f_axis_0>np.floor(filter_fft.shape[0]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[0]/2))+1)
                    f_axis_0=np.fft.fftshift(f_axis_0)
                    f_axis_1=np.arange(filter_fft.shape[1])
                    f_axis_1[f_axis_1>np.floor(filter_fft.shape[1]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[1]/2))+1)
                    f_axis_1=np.fft.fftshift(f_axis_1)

                    Y,X=np.meshgrid(f_axis_0,f_axis_1)
                    euc_dist=np.sqrt(X**2+Y**2)
                    mean_f_response=np.mean(euc_dist*filter_fft)
                    list_f_response[filter_counter]=mean_f_response

                    filter_counter+=1
            hist,bins=np.histogram(list_f_response,bins=100)
            plt.plot(hist)
            plt.savefig("fig_fft"+layer.name+".png")
            plt.pause(1)
# Out:
# 1 conv2d_1 (7, 7, 1, 64)
# 2 conv2d_2 (3, 3, 64, 64)
# 3 conv2d_3 (3, 3, 64, 64)
# 4 conv2d_4 (3, 3, 64, 64)
# 5 conv2d_5 (3, 3, 64, 64)
# 6 conv2d_6 (3, 3, 64, 128)
# 7 conv2d_7 (3, 3, 128, 128)
# 8 conv2d_9 (3, 3, 128, 128)
# 9 conv2d_10 (3, 3, 128, 128)
# 10 conv2d_11 (3, 3, 128, 256)
# 11 conv2d_12 (3, 3, 256, 256)
# 12 conv2d_14 (3, 3, 256, 256)
# 13 conv2d_15 (3, 3, 256, 256)
# 14 conv2d_16 (3, 3, 256, 512)
# 15 conv2d_17 (3, 3, 512, 512)
# 16 conv2d_19 (3, 3, 512, 512)
# 17 conv2d_20 (3, 3, 512, 512)
