# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import MaxPooling2D, AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# example of loading the fashion mnist dataset
from matplotlib import pyplot
from keras.datasets import fashion_mnist
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (X_train.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (X_test.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 1us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
from scipy.ndimage import gaussian_filter
io=[]
for i in range(60000):
  Gaussian =gaussian_filter(X_train[i], sigma=4)
  io.append(Gaussian)
io=np.array(io)
print(io.shape)
op=[]
for j in range(10000):
  Gaussian =gaussian_filter(X_test[j], sigma=4)
  op.append(Gaussian)
op=np.array(op)
print(op.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
#Summary after Gaussian filter
print('Train: X=%s, y=%s' % (io.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (op.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(io[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
#Defining constants
epochs = 200
batch_size = 100
data_augmentation = False
img_size = 28

num_classes = 10
num_filters = 64
num_blocks = 4
num_sub_blocks = 2
use_max_pool = False

# %%
x_train = io.reshape(io.shape[0],img_size,img_size,1)
x_test = op.reshape(op.shape[0],img_size,img_size,1)
input_size = (img_size, img_size,1)
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('Y_train shape:', Y_train.shape)

#Converting labels to one-hot vectors
y_train = keras.utils.to_categorical(Y_train, num_classes)
y_test = keras.utils.to_categorical(Y_test,num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Y_train shape: (60000,)

# %%
#Creating model based on ResNet published archietecture
inputs = Input(shape=input_size)
x = Conv2D(num_filters, padding='same', 
           kernel_initializer='he_normal', 
           kernel_size=7, strides=2,
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

#Check by applying max pooling later (setting it false as size of image is small i.e. 28x28)
if use_max_pool:
    x = MaxPooling2D(pool_size=3,padding='same', strides=2)(x)
    num_blocks =3
#Creating Conv base stack 

# Instantiate convolutional base (stack of blocks).
for i in range(num_blocks):
    for j in range(num_sub_blocks):
        strides = 1
        is_first_layer_but_not_first_block = j == 0 and i > 0
        if is_first_layer_but_not_first_block:
            strides = 2
        #Creating residual mapping using y
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   strides=strides,
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if is_first_layer_but_not_first_block:
            x = Conv2D(num_filters,
                       kernel_size=1,
                       padding='same',
                       strides=2,
                       kernel_initializer='he_normal',
                       kernel_regularizer=l2(1e-4))(x)
        #Adding back residual mapping
        x = keras.layers.add([x, y])
        x = Activation('relu')(x)

    num_filters = 2 * num_filters

# Add classifier on top.
x = AveragePooling2D()(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                activation='softmax',
                kernel_initializer='he_normal')(y)

# Instantiate and compile model.
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 14, 14, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 14, 14, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 64)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 64)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 128)    8320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 7, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 128)    0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 128)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 128)    0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 256)    295168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 256)    33024       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 256)    0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 512)    1180160     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 512)    131584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 512)    0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 512)    0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 512)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,186,186
# Trainable params: 11,178,378
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'saved_model')
model_name = 'fmnist_resnet_model_gaussian_filter_4.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir,model_name)
print(filepath)
# Prepare callbacks for model saving and for learning rate decaying.
checkpoint = ModelCheckpoint(filepath=filepath,
                             verbose=1,
                             save_best_only=True)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer]
# Out:
# /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5

# %%
if not data_augmentation:
    print('Using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
# Out:
# Using data augmentation.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 43s 716us/step - loss: 1.3984 - accuracy: 0.7818 - val_loss: 1.1956 - val_accuracy: 0.7847
#
# Epoch 00001: val_loss improved from inf to 1.19563, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 2/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.9307 - accuracy: 0.8442 - val_loss: 0.9013 - val_accuracy: 0.8164
#
# Epoch 00002: val_loss improved from 1.19563 to 0.90132, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 3/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.7450 - accuracy: 0.8540 - val_loss: 0.7055 - val_accuracy: 0.8473
#
# Epoch 00003: val_loss improved from 0.90132 to 0.70554, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 4/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.6376 - accuracy: 0.8623 - val_loss: 0.7004 - val_accuracy: 0.8341
#
# Epoch 00004: val_loss improved from 0.70554 to 0.70036, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 5/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.5749 - accuracy: 0.8688 - val_loss: 0.5927 - val_accuracy: 0.8564
#
# Epoch 00005: val_loss improved from 0.70036 to 0.59271, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 6/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.5430 - accuracy: 0.8696 - val_loss: 0.6013 - val_accuracy: 0.8383
#
# Epoch 00006: val_loss did not improve from 0.59271
# Epoch 7/200
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.5160 - accuracy: 0.8716 - val_loss: 0.5841 - val_accuracy: 0.8523
#
# Epoch 00007: val_loss improved from 0.59271 to 0.58405, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 8/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.4977 - accuracy: 0.8747 - val_loss: 0.5643 - val_accuracy: 0.8554
#
# Epoch 00008: val_loss improved from 0.58405 to 0.56429, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 9/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.4818 - accuracy: 0.8764 - val_loss: 0.5347 - val_accuracy: 0.8482
#
# Epoch 00009: val_loss improved from 0.56429 to 0.53471, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 10/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.4697 - accuracy: 0.8795 - val_loss: 0.5146 - val_accuracy: 0.8618
#
# Epoch 00010: val_loss improved from 0.53471 to 0.51461, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 11/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.4601 - accuracy: 0.8809 - val_loss: 0.5035 - val_accuracy: 0.8656
#
# Epoch 00011: val_loss improved from 0.51461 to 0.50350, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 12/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.4504 - accuracy: 0.8820 - val_loss: 0.5010 - val_accuracy: 0.8666
#
# Epoch 00012: val_loss improved from 0.50350 to 0.50096, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 13/200
# 60000/60000 [==============================] - 32s 527us/step - loss: 0.4419 - accuracy: 0.8844 - val_loss: 0.4727 - val_accuracy: 0.8777
#
# Epoch 00013: val_loss improved from 0.50096 to 0.47272, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 14/200
# 60000/60000 [==============================] - 31s 525us/step - loss: 0.4307 - accuracy: 0.8865 - val_loss: 0.5162 - val_accuracy: 0.8569
#
# Epoch 00014: val_loss did not improve from 0.47272
# Epoch 15/200
# 60000/60000 [==============================] - 32s 525us/step - loss: 0.4180 - accuracy: 0.8903 - val_loss: 0.4783 - val_accuracy: 0.8666
#
# Epoch 00015: val_loss did not improve from 0.47272
# Epoch 16/200
# 60000/60000 [==============================] - 31s 524us/step - loss: 0.4118 - accuracy: 0.8931 - val_loss: 0.4998 - val_accuracy: 0.8622
#
# Epoch 00016: val_loss did not improve from 0.47272
# Epoch 17/200
# 60000/60000 [==============================] - 32s 527us/step - loss: 0.4000 - accuracy: 0.8954 - val_loss: 0.4860 - val_accuracy: 0.8607
#
# Epoch 00017: val_loss did not improve from 0.47272
# Epoch 18/200
# 60000/60000 [==============================] - 31s 521us/step - loss: 0.4198 - accuracy: 0.8963 - val_loss: 0.4985 - val_accuracy: 0.8676
#
# Epoch 00018: val_loss did not improve from 0.47272
# Epoch 19/200
# 60000/60000 [==============================] - 31s 522us/step - loss: 0.3379 - accuracy: 0.9191 - val_loss: 0.4284 - val_accuracy: 0.8865
#
# Epoch 00019: val_loss improved from 0.47272 to 0.42845, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 20/200
# 60000/60000 [==============================] - 31s 525us/step - loss: 0.2989 - accuracy: 0.9281 - val_loss: 0.4389 - val_accuracy: 0.8820
#
# Epoch 00020: val_loss did not improve from 0.42845
# Epoch 21/200
# 60000/60000 [==============================] - 32s 525us/step - loss: 0.2788 - accuracy: 0.9324 - val_loss: 0.4185 - val_accuracy: 0.8882
#
# Epoch 00021: val_loss improved from 0.42845 to 0.41846, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_4.h5
# Epoch 22/200
# 60000/60000 [==============================] - 32s 526us/step - loss: 0.2581 - accuracy: 0.9395 - val_loss: 0.4388 - val_accuracy: 0.8816
#
# Epoch 00022: val_loss did not improve from 0.41846
# Epoch 23/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.2420 - accuracy: 0.9446 - val_loss: 0.4475 - val_accuracy: 0.8880
#
# Epoch 00023: val_loss did not improve from 0.41846
# Epoch 24/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.2302 - accuracy: 0.9495 - val_loss: 0.4547 - val_accuracy: 0.8856
#
# Epoch 00024: val_loss did not improve from 0.41846
# Epoch 25/200
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.2176 - accuracy: 0.9542 - val_loss: 0.4753 - val_accuracy: 0.8860
#
# Epoch 00025: val_loss did not improve from 0.41846
# Epoch 26/200
# 60000/60000 [==============================] - 31s 521us/step - loss: 0.2041 - accuracy: 0.9601 - val_loss: 0.5024 - val_accuracy: 0.8851
#
# Epoch 00026: val_loss did not improve from 0.41846
# Epoch 27/200
# 60000/60000 [==============================] - 31s 521us/step - loss: 0.1544 - accuracy: 0.9795 - val_loss: 0.5343 - val_accuracy: 0.8890
#
# Epoch 00027: val_loss did not improve from 0.41846
# Epoch 28/200
# 60000/60000 [==============================] - 31s 520us/step - loss: 0.1338 - accuracy: 0.9863 - val_loss: 0.5924 - val_accuracy: 0.8889
#
# Epoch 00028: val_loss did not improve from 0.41846
# Epoch 29/200
# 60000/60000 [==============================] - 31s 523us/step - loss: 0.1236 - accuracy: 0.9892 - val_loss: 0.6548 - val_accuracy: 0.8859
#
# Epoch 00029: val_loss did not improve from 0.41846
# Epoch 30/200
# 60000/60000 [==============================] - 31s 523us/step - loss: 0.1167 - accuracy: 0.9914 - val_loss: 0.6790 - val_accuracy: 0.8849
#
# Epoch 00030: val_loss did not improve from 0.41846
# Epoch 31/200
# 60000/60000 [==============================] - 31s 522us/step - loss: 0.1114 - accuracy: 0.9927 - val_loss: 0.7008 - val_accuracy: 0.8871
#
# Epoch 00031: val_loss did not improve from 0.41846
# Epoch 32/200
# 60000/60000 [==============================] - 31s 524us/step - loss: 0.0975 - accuracy: 0.9974 - val_loss: 0.8310 - val_accuracy: 0.8863
#
# Epoch 00032: val_loss did not improve from 0.41846
# Epoch 33/200
# 60000/60000 [==============================] - 31s 521us/step - loss: 0.0926 - accuracy: 0.9986 - val_loss: 0.9393 - val_accuracy: 0.8873
#
# Epoch 00033: val_loss did not improve from 0.41846
# Epoch 34/200
# 60000/60000 [==============================] - 32s 527us/step - loss: 0.0918 - accuracy: 0.9986 - val_loss: 0.9254 - val_accuracy: 0.8868
#
# Epoch 00034: val_loss did not improve from 0.41846
# Epoch 35/200
# 60000/60000 [==============================] - 32s 526us/step - loss: 0.0901 - accuracy: 0.9990 - val_loss: 0.9350 - val_accuracy: 0.8864
#
# Epoch 00035: val_loss did not improve from 0.41846
# Epoch 36/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0885 - accuracy: 0.9992 - val_loss: 0.9744 - val_accuracy: 0.8876
#
# Epoch 00036: val_loss did not improve from 0.41846
# Epoch 37/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0864 - accuracy: 0.9998 - val_loss: 1.0551 - val_accuracy: 0.8887
#
# Epoch 00037: val_loss did not improve from 0.41846
# Epoch 38/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 1.1123 - val_accuracy: 0.8882
#
# Epoch 00038: val_loss did not improve from 0.41846
# Epoch 39/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0850 - accuracy: 0.9998 - val_loss: 1.1528 - val_accuracy: 0.8873
#
# Epoch 00039: val_loss did not improve from 0.41846
# Epoch 40/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.0847 - accuracy: 0.9998 - val_loss: 1.1420 - val_accuracy: 0.8868
#
# Epoch 00040: val_loss did not improve from 0.41846
# Epoch 41/200
# 60000/60000 [==============================] - 32s 527us/step - loss: 0.0839 - accuracy: 0.9999 - val_loss: 1.1584 - val_accuracy: 0.8869
#
# Epoch 00041: val_loss did not improve from 0.41846
# Epoch 42/200
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.0834 - accuracy: 0.9999 - val_loss: 1.1622 - val_accuracy: 0.8871
#
# Epoch 00042: val_loss did not improve from 0.41846
# Epoch 43/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.0831 - accuracy: 0.9999 - val_loss: 1.1709 - val_accuracy: 0.8875
#
# Epoch 00043: val_loss did not improve from 0.41846
# Epoch 44/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 1.1789 - val_accuracy: 0.8884
#
# Epoch 00044: val_loss did not improve from 0.41846
# Epoch 45/200
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 1.1935 - val_accuracy: 0.8873
#
# Epoch 00045: val_loss did not improve from 0.41846
# Epoch 46/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0824 - accuracy: 0.9999 - val_loss: 1.1974 - val_accuracy: 0.8885
#
# Epoch 00046: val_loss did not improve from 0.41846
# Epoch 47/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.0822 - accuracy: 0.9999 - val_loss: 1.1997 - val_accuracy: 0.8885
#
# Epoch 00047: val_loss did not improve from 0.41846
# Epoch 48/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0820 - accuracy: 0.9999 - val_loss: 1.1965 - val_accuracy: 0.8885
#
# Epoch 00048: val_loss did not improve from 0.41846
# Epoch 49/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0821 - accuracy: 0.9999 - val_loss: 1.1984 - val_accuracy: 0.8881
#
# Epoch 00049: val_loss did not improve from 0.41846
# Epoch 50/200
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 1.1997 - val_accuracy: 0.8886
#
# Epoch 00050: val_loss did not improve from 0.41846
# Epoch 51/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 1.1993 - val_accuracy: 0.8882
#
# Epoch 00051: val_loss did not improve from 0.41846
# Epoch 52/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 1.2022 - val_accuracy: 0.8882
#
# Epoch 00052: val_loss did not improve from 0.41846
# Epoch 53/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.2012 - val_accuracy: 0.8888
#
# Epoch 00053: val_loss did not improve from 0.41846
# Epoch 54/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 1.2042 - val_accuracy: 0.8886
#
# Epoch 00054: val_loss did not improve from 0.41846
# Epoch 55/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 1.2021 - val_accuracy: 0.8886
#
# Epoch 00055: val_loss did not improve from 0.41846
# Epoch 56/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 1.2057 - val_accuracy: 0.8887
#
# Epoch 00056: val_loss did not improve from 0.41846
# Epoch 57/200
# 60000/60000 [==============================] - 32s 530us/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 1.2066 - val_accuracy: 0.8884
#
# Epoch 00057: val_loss did not improve from 0.41846
# Epoch 58/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 1.2072 - val_accuracy: 0.8882
#
# Epoch 00058: val_loss did not improve from 0.41846
# Epoch 59/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 1.2091 - val_accuracy: 0.8882
#
# Epoch 00059: val_loss did not improve from 0.41846
# Epoch 60/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 1.2108 - val_accuracy: 0.8881
#
# Epoch 00060: val_loss did not improve from 0.41846
# Epoch 61/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 1.2102 - val_accuracy: 0.8891
#
# Epoch 00061: val_loss did not improve from 0.41846
# Epoch 62/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0811 - accuracy: 1.0000 - val_loss: 1.2118 - val_accuracy: 0.8882
#
# Epoch 00062: val_loss did not improve from 0.41846
# Epoch 63/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0810 - accuracy: 1.0000 - val_loss: 1.2119 - val_accuracy: 0.8887
#
# Epoch 00063: val_loss did not improve from 0.41846
# Epoch 64/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0810 - accuracy: 1.0000 - val_loss: 1.2096 - val_accuracy: 0.8885
#
# Epoch 00064: val_loss did not improve from 0.41846
# Epoch 65/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0809 - accuracy: 1.0000 - val_loss: 1.2139 - val_accuracy: 0.8889
#
# Epoch 00065: val_loss did not improve from 0.41846
# Epoch 66/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 1.2130 - val_accuracy: 0.8883
#
# Epoch 00066: val_loss did not improve from 0.41846
# Epoch 67/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 1.2182 - val_accuracy: 0.8887
#
# Epoch 00067: val_loss did not improve from 0.41846
# Epoch 68/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 1.2154 - val_accuracy: 0.8882
#
# Epoch 00068: val_loss did not improve from 0.41846
# Epoch 69/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0806 - accuracy: 1.0000 - val_loss: 1.2206 - val_accuracy: 0.8885
#
# Epoch 00069: val_loss did not improve from 0.41846
# Epoch 70/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0806 - accuracy: 1.0000 - val_loss: 1.2191 - val_accuracy: 0.8883
#
# Epoch 00070: val_loss did not improve from 0.41846
# Epoch 71/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0805 - accuracy: 1.0000 - val_loss: 1.2217 - val_accuracy: 0.8880
#
# Epoch 00071: val_loss did not improve from 0.41846
# Epoch 72/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0804 - accuracy: 1.0000 - val_loss: 1.2167 - val_accuracy: 0.8889
#
# Epoch 00072: val_loss did not improve from 0.41846
# Epoch 73/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0803 - accuracy: 1.0000 - val_loss: 1.2217 - val_accuracy: 0.8885
#
# Epoch 00073: val_loss did not improve from 0.41846
# Epoch 74/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0803 - accuracy: 1.0000 - val_loss: 1.2221 - val_accuracy: 0.8890
#
# Epoch 00074: val_loss did not improve from 0.41846
# Epoch 75/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0802 - accuracy: 1.0000 - val_loss: 1.2234 - val_accuracy: 0.8879
#
# Epoch 00075: val_loss did not improve from 0.41846
# Epoch 76/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.0802 - accuracy: 0.9999 - val_loss: 1.2207 - val_accuracy: 0.8887
#
# Epoch 00076: val_loss did not improve from 0.41846
# Epoch 77/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0801 - accuracy: 1.0000 - val_loss: 1.2218 - val_accuracy: 0.8888
#
# Epoch 00077: val_loss did not improve from 0.41846
# Epoch 78/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0801 - accuracy: 1.0000 - val_loss: 1.2233 - val_accuracy: 0.8878
#
# Epoch 00078: val_loss did not improve from 0.41846
# Epoch 79/200
# 60000/60000 [==============================] - 32s 533us/step - loss: 0.0800 - accuracy: 0.9999 - val_loss: 1.2281 - val_accuracy: 0.8880
#
# Epoch 00079: val_loss did not improve from 0.41846
# Epoch 80/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0799 - accuracy: 1.0000 - val_loss: 1.2248 - val_accuracy: 0.8879
#
# Epoch 00080: val_loss did not improve from 0.41846
# Epoch 81/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0799 - accuracy: 1.0000 - val_loss: 1.2268 - val_accuracy: 0.8879
#
# Epoch 00081: val_loss did not improve from 0.41846
# Epoch 82/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 1.2256 - val_accuracy: 0.8882
#
# Epoch 00082: val_loss did not improve from 0.41846
# Epoch 83/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 1.2258 - val_accuracy: 0.8880
#
# Epoch 00083: val_loss did not improve from 0.41846
# Epoch 84/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 1.2292 - val_accuracy: 0.8885
#
# Epoch 00084: val_loss did not improve from 0.41846
# Epoch 85/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0796 - accuracy: 1.0000 - val_loss: 1.2291 - val_accuracy: 0.8887
#
# Epoch 00085: val_loss did not improve from 0.41846
# Epoch 86/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0796 - accuracy: 1.0000 - val_loss: 1.2288 - val_accuracy: 0.8889
#
# Epoch 00086: val_loss did not improve from 0.41846
# Epoch 87/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0795 - accuracy: 1.0000 - val_loss: 1.2289 - val_accuracy: 0.8884
#
# Epoch 00087: val_loss did not improve from 0.41846
# Epoch 88/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 1.2287 - val_accuracy: 0.8887
#
# Epoch 00088: val_loss did not improve from 0.41846
# Epoch 89/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0793 - accuracy: 1.0000 - val_loss: 1.2306 - val_accuracy: 0.8888
#
# Epoch 00089: val_loss did not improve from 0.41846
# Epoch 90/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 1.2311 - val_accuracy: 0.8883
#
# Epoch 00090: val_loss did not improve from 0.41846
# Epoch 91/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 1.2330 - val_accuracy: 0.8885
#
# Epoch 00091: val_loss did not improve from 0.41846
# Epoch 92/200
# 60000/60000 [==============================] - 33s 544us/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 1.2323 - val_accuracy: 0.8884
#
# Epoch 00092: val_loss did not improve from 0.41846
# Epoch 93/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 1.2334 - val_accuracy: 0.8886
#
# Epoch 00093: val_loss did not improve from 0.41846
# Epoch 94/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0789 - accuracy: 1.0000 - val_loss: 1.2335 - val_accuracy: 0.8883
#
# Epoch 00094: val_loss did not improve from 0.41846
# Epoch 95/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0788 - accuracy: 1.0000 - val_loss: 1.2360 - val_accuracy: 0.8892
#
# Epoch 00095: val_loss did not improve from 0.41846
# Epoch 96/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0787 - accuracy: 0.9999 - val_loss: 1.2363 - val_accuracy: 0.8883
#
# Epoch 00096: val_loss did not improve from 0.41846
# Epoch 97/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 1.2366 - val_accuracy: 0.8887
#
# Epoch 00097: val_loss did not improve from 0.41846
# Epoch 98/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0785 - accuracy: 1.0000 - val_loss: 1.2343 - val_accuracy: 0.8889
#
# Epoch 00098: val_loss did not improve from 0.41846
# Epoch 99/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0784 - accuracy: 1.0000 - val_loss: 1.2355 - val_accuracy: 0.8886
#
# Epoch 00099: val_loss did not improve from 0.41846
# Epoch 100/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0783 - accuracy: 1.0000 - val_loss: 1.2413 - val_accuracy: 0.8887
#
# Epoch 00100: val_loss did not improve from 0.41846
# Epoch 101/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 1.2371 - val_accuracy: 0.8890
#
# Epoch 00101: val_loss did not improve from 0.41846
# Epoch 102/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 1.2409 - val_accuracy: 0.8893
#
# Epoch 00102: val_loss did not improve from 0.41846
# Epoch 103/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0781 - accuracy: 1.0000 - val_loss: 1.2401 - val_accuracy: 0.8889
#
# Epoch 00103: val_loss did not improve from 0.41846
# Epoch 104/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0780 - accuracy: 1.0000 - val_loss: 1.2430 - val_accuracy: 0.8888
#
# Epoch 00104: val_loss did not improve from 0.41846
# Epoch 105/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0779 - accuracy: 1.0000 - val_loss: 1.2452 - val_accuracy: 0.8888
#
# Epoch 00105: val_loss did not improve from 0.41846
# Epoch 106/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0779 - accuracy: 1.0000 - val_loss: 1.2432 - val_accuracy: 0.8893
#
# Epoch 00106: val_loss did not improve from 0.41846
# Epoch 107/200
# 60000/60000 [==============================] - 33s 542us/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 1.2429 - val_accuracy: 0.8891
#
# Epoch 00107: val_loss did not improve from 0.41846
# Epoch 108/200
# 60000/60000 [==============================] - 33s 549us/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 1.2399 - val_accuracy: 0.8893
#
# Epoch 00108: val_loss did not improve from 0.41846
# Epoch 109/200
# 60000/60000 [==============================] - 33s 550us/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 1.2443 - val_accuracy: 0.8891
#
# Epoch 00109: val_loss did not improve from 0.41846
# Epoch 110/200
# 60000/60000 [==============================] - 33s 548us/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 1.2418 - val_accuracy: 0.8884
#
# Epoch 00110: val_loss did not improve from 0.41846
# Epoch 111/200
# 60000/60000 [==============================] - 33s 549us/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 1.2456 - val_accuracy: 0.8892
#
# Epoch 00111: val_loss did not improve from 0.41846
# Epoch 112/200
# 60000/60000 [==============================] - 33s 548us/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 1.2417 - val_accuracy: 0.8887
#
# Epoch 00112: val_loss did not improve from 0.41846
# Epoch 113/200
# 60000/60000 [==============================] - 33s 546us/step - loss: 0.0773 - accuracy: 1.0000 - val_loss: 1.2451 - val_accuracy: 0.8887
#
# Epoch 00113: val_loss did not improve from 0.41846
# Epoch 114/200
# 60000/60000 [==============================] - 33s 547us/step - loss: 0.0773 - accuracy: 1.0000 - val_loss: 1.2480 - val_accuracy: 0.8889
#
# Epoch 00114: val_loss did not improve from 0.41846
# Epoch 115/200
# 60000/60000 [==============================] - 33s 547us/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 1.2466 - val_accuracy: 0.8886
#
# Epoch 00115: val_loss did not improve from 0.41846
# Epoch 116/200
# 60000/60000 [==============================] - 33s 546us/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 1.2474 - val_accuracy: 0.8884
#
# Epoch 00116: val_loss did not improve from 0.41846
# Epoch 117/200
# 60000/60000 [==============================] - 33s 548us/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 1.2484 - val_accuracy: 0.8888
#
# Epoch 00117: val_loss did not improve from 0.41846
# Epoch 118/200
# 60000/60000 [==============================] - 33s 544us/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 1.2469 - val_accuracy: 0.8890
#
# Epoch 00118: val_loss did not improve from 0.41846
# Epoch 119/200
# 60000/60000 [==============================] - 33s 542us/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 1.2496 - val_accuracy: 0.8886
#
# Epoch 00119: val_loss did not improve from 0.41846
# Epoch 120/200
# 60000/60000 [==============================] - 33s 543us/step - loss: 0.0769 - accuracy: 1.0000 - val_loss: 1.2487 - val_accuracy: 0.8885
#
# Epoch 00120: val_loss did not improve from 0.41846
# Epoch 121/200
# 60000/60000 [==============================] - 33s 547us/step - loss: 0.0768 - accuracy: 1.0000 - val_loss: 1.2473 - val_accuracy: 0.8883
#
# Epoch 00121: val_loss did not improve from 0.41846
# Epoch 122/200
# 60000/60000 [==============================] - 33s 548us/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 1.2464 - val_accuracy: 0.8892
#
# Epoch 00122: val_loss did not improve from 0.41846
# Epoch 123/200
# 60000/60000 [==============================] - 33s 542us/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 1.2488 - val_accuracy: 0.8892
#
# Epoch 00123: val_loss did not improve from 0.41846
# Epoch 124/200
# 60000/60000 [==============================] - 33s 544us/step - loss: 0.0766 - accuracy: 1.0000 - val_loss: 1.2509 - val_accuracy: 0.8890
#
# Epoch 00124: val_loss did not improve from 0.41846
# Epoch 125/200
# 60000/60000 [==============================] - 33s 545us/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 1.2446 - val_accuracy: 0.8892
#
# Epoch 00125: val_loss did not improve from 0.41846
# Epoch 126/200
# 60000/60000 [==============================] - 33s 544us/step - loss: 0.0764 - accuracy: 1.0000 - val_loss: 1.2466 - val_accuracy: 0.8893
#
# Epoch 00126: val_loss did not improve from 0.41846
# Epoch 127/200
# 60000/60000 [==============================] - 33s 543us/step - loss: 0.0764 - accuracy: 1.0000 - val_loss: 1.2471 - val_accuracy: 0.8888
#
# Epoch 00127: val_loss did not improve from 0.41846
# Epoch 128/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0763 - accuracy: 1.0000 - val_loss: 1.2516 - val_accuracy: 0.8886
#
# Epoch 00128: val_loss did not improve from 0.41846
# Epoch 129/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0763 - accuracy: 1.0000 - val_loss: 1.2501 - val_accuracy: 0.8884
#
# Epoch 00129: val_loss did not improve from 0.41846
# Epoch 130/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0762 - accuracy: 1.0000 - val_loss: 1.2458 - val_accuracy: 0.8879
#
# Epoch 00130: val_loss did not improve from 0.41846
# Epoch 131/200
# 60000/60000 [==============================] - 33s 543us/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 1.2487 - val_accuracy: 0.8884
#
# Epoch 00131: val_loss did not improve from 0.41846
# Epoch 132/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0760 - accuracy: 1.0000 - val_loss: 1.2485 - val_accuracy: 0.8886
#
# Epoch 00132: val_loss did not improve from 0.41846
# Epoch 133/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0759 - accuracy: 1.0000 - val_loss: 1.2493 - val_accuracy: 0.8887
#
# Epoch 00133: val_loss did not improve from 0.41846
# Epoch 134/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 1.2486 - val_accuracy: 0.8885
#
# Epoch 00134: val_loss did not improve from 0.41846
# Epoch 135/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 1.2538 - val_accuracy: 0.8880
#
# Epoch 00135: val_loss did not improve from 0.41846
# Epoch 136/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0757 - accuracy: 1.0000 - val_loss: 1.2601 - val_accuracy: 0.8881
#
# Epoch 00136: val_loss did not improve from 0.41846
# Epoch 137/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 1.2519 - val_accuracy: 0.8883
#
# Epoch 00137: val_loss did not improve from 0.41846
# Epoch 138/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0755 - accuracy: 1.0000 - val_loss: 1.2516 - val_accuracy: 0.8882
#
# Epoch 00138: val_loss did not improve from 0.41846
# Epoch 139/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0755 - accuracy: 1.0000 - val_loss: 1.2498 - val_accuracy: 0.8879
#
# Epoch 00139: val_loss did not improve from 0.41846
# Epoch 140/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0754 - accuracy: 1.0000 - val_loss: 1.2557 - val_accuracy: 0.8886
#
# Epoch 00140: val_loss did not improve from 0.41846
# Epoch 141/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 1.2548 - val_accuracy: 0.8885
#
# Epoch 00141: val_loss did not improve from 0.41846
# Epoch 142/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 1.2546 - val_accuracy: 0.8883
#
# Epoch 00142: val_loss did not improve from 0.41846
# Epoch 143/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 1.2574 - val_accuracy: 0.8884
#
# Epoch 00143: val_loss did not improve from 0.41846
# Epoch 144/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0751 - accuracy: 1.0000 - val_loss: 1.2586 - val_accuracy: 0.8887
#
# Epoch 00144: val_loss did not improve from 0.41846
# Epoch 145/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 1.2565 - val_accuracy: 0.8881
#
# Epoch 00145: val_loss did not improve from 0.41846
# Epoch 146/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 1.2575 - val_accuracy: 0.8889
#
# Epoch 00146: val_loss did not improve from 0.41846
# Epoch 147/200
# 60000/60000 [==============================] - 33s 542us/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 1.2563 - val_accuracy: 0.8889
#
# Epoch 00147: val_loss did not improve from 0.41846
# Epoch 148/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0748 - accuracy: 1.0000 - val_loss: 1.2546 - val_accuracy: 0.8890
#
# Epoch 00148: val_loss did not improve from 0.41846
# Epoch 149/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0748 - accuracy: 1.0000 - val_loss: 1.2625 - val_accuracy: 0.8894
#
# Epoch 00149: val_loss did not improve from 0.41846
# Epoch 150/200
# 60000/60000 [==============================] - 33s 543us/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 1.2602 - val_accuracy: 0.8888
#
# Epoch 00150: val_loss did not improve from 0.41846
# Epoch 151/200
# 60000/60000 [==============================] - 33s 542us/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 1.2565 - val_accuracy: 0.8890
#
# Epoch 00151: val_loss did not improve from 0.41846
# Epoch 152/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0746 - accuracy: 0.9999 - val_loss: 1.2554 - val_accuracy: 0.8893
#
# Epoch 00152: val_loss did not improve from 0.41846
# Epoch 153/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0745 - accuracy: 1.0000 - val_loss: 1.2593 - val_accuracy: 0.8893
#
# Epoch 00153: val_loss did not improve from 0.41846
# Epoch 154/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0744 - accuracy: 1.0000 - val_loss: 1.2586 - val_accuracy: 0.8889
#
# Epoch 00154: val_loss did not improve from 0.41846
# Epoch 155/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0745 - accuracy: 1.0000 - val_loss: 1.2606 - val_accuracy: 0.8896
#
# Epoch 00155: val_loss did not improve from 0.41846
# Epoch 156/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.8893
#
# Epoch 00156: val_loss did not improve from 0.41846
# Epoch 157/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 1.2647 - val_accuracy: 0.8894
#
# Epoch 00157: val_loss did not improve from 0.41846
# Epoch 158/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 1.2592 - val_accuracy: 0.8878
#
# Epoch 00158: val_loss did not improve from 0.41846
# Epoch 159/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0742 - accuracy: 1.0000 - val_loss: 1.2640 - val_accuracy: 0.8891
#
# Epoch 00159: val_loss did not improve from 0.41846
# Epoch 160/200
# 60000/60000 [==============================] - 32s 538us/step - loss: 0.0742 - accuracy: 0.9999 - val_loss: 1.2561 - val_accuracy: 0.8877
#
# Epoch 00160: val_loss did not improve from 0.41846
# Epoch 161/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 1.2618 - val_accuracy: 0.8875
#
# Epoch 00161: val_loss did not improve from 0.41846
# Epoch 162/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 1.2615 - val_accuracy: 0.8884
#
# Epoch 00162: val_loss did not improve from 0.41846
# Epoch 163/200
# 60000/60000 [==============================] - 32s 535us/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 1.2594 - val_accuracy: 0.8882
#
# Epoch 00163: val_loss did not improve from 0.41846
# Epoch 164/200
# 60000/60000 [==============================] - 33s 546us/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 1.2607 - val_accuracy: 0.8891
#
# Epoch 00164: val_loss did not improve from 0.41846
# Epoch 165/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 1.2611 - val_accuracy: 0.8887
#
# Epoch 00165: val_loss did not improve from 0.41846
# Epoch 166/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 1.2634 - val_accuracy: 0.8889
#
# Epoch 00166: val_loss did not improve from 0.41846
# Epoch 167/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0737 - accuracy: 1.0000 - val_loss: 1.2589 - val_accuracy: 0.8887
#
# Epoch 00167: val_loss did not improve from 0.41846
# Epoch 168/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0737 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.8883
#
# Epoch 00168: val_loss did not improve from 0.41846
# Epoch 169/200
# 60000/60000 [==============================] - 32s 540us/step - loss: 0.0736 - accuracy: 1.0000 - val_loss: 1.2553 - val_accuracy: 0.8874
#
# Epoch 00169: val_loss did not improve from 0.41846
# Epoch 170/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 1.2601 - val_accuracy: 0.8884
#
# Epoch 00170: val_loss did not improve from 0.41846
# Epoch 171/200
# 60000/60000 [==============================] - 33s 543us/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 1.2617 - val_accuracy: 0.8888
#
# Epoch 00171: val_loss did not improve from 0.41846
# Epoch 172/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 1.2578 - val_accuracy: 0.8884
#
# Epoch 00172: val_loss did not improve from 0.41846
# Epoch 173/200
# 60000/60000 [==============================] - 32s 539us/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 1.2618 - val_accuracy: 0.8882
#
# Epoch 00173: val_loss did not improve from 0.41846
# Epoch 174/200
# 60000/60000 [==============================] - 32s 541us/step - loss: 0.0732 - accuracy: 1.0000 - val_loss: 1.2617 - val_accuracy: 0.8882
#
# Epoch 00174: val_loss did not improve from 0.41846
# Epoch 175/200
# 60000/60000 [==============================] - 32s 537us/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 1.2617 - val_accuracy: 0.8885
#
# Epoch 00175: val_loss did not improve from 0.41846
# Epoch 176/200
# 60000/60000 [==============================] - 32s 536us/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 1.2629 - val_accuracy: 0.8892
#
# Epoch 00176: val_loss did not improve from 0.41846
# Epoch 177/200
# 60000/60000 [==============================] - 32s 534us/step - loss: 0.0730 - accuracy: 0.9999 - val_loss: 1.2647 - val_accuracy: 0.8877
#
# Epoch 00177: val_loss did not improve from 0.41846
# Epoch 178/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.0730 - accuracy: 1.0000 - val_loss: 1.2611 - val_accuracy: 0.8880
#
# Epoch 00178: val_loss did not improve from 0.41846
# Epoch 179/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 1.2670 - val_accuracy: 0.8876
#
# Epoch 00179: val_loss did not improve from 0.41846
# Epoch 180/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 1.2624 - val_accuracy: 0.8885
#
# Epoch 00180: val_loss did not improve from 0.41846
# Epoch 181/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 1.2661 - val_accuracy: 0.8881
#
# Epoch 00181: val_loss did not improve from 0.41846
# Epoch 182/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 1.2620 - val_accuracy: 0.8878
#
# Epoch 00182: val_loss did not improve from 0.41846
# Epoch 183/200
# 60000/60000 [==============================] - 31s 524us/step - loss: 0.0726 - accuracy: 1.0000 - val_loss: 1.2615 - val_accuracy: 0.8887
#
# Epoch 00183: val_loss did not improve from 0.41846
# Epoch 184/200
# 60000/60000 [==============================] - 32s 526us/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 1.2666 - val_accuracy: 0.8888
#
# Epoch 00184: val_loss did not improve from 0.41846
# Epoch 185/200
# 60000/60000 [==============================] - 32s 527us/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 1.2662 - val_accuracy: 0.8882
#
# Epoch 00185: val_loss did not improve from 0.41846
# Epoch 186/200
# 60000/60000 [==============================] - 31s 524us/step - loss: 0.0724 - accuracy: 1.0000 - val_loss: 1.2636 - val_accuracy: 0.8887
#
# Epoch 00186: val_loss did not improve from 0.41846
# Epoch 187/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.2654 - val_accuracy: 0.8879
#
# Epoch 00187: val_loss did not improve from 0.41846
# Epoch 188/200
# 60000/60000 [==============================] - 32s 532us/step - loss: 0.0722 - accuracy: 1.0000 - val_loss: 1.2642 - val_accuracy: 0.8888
#
# Epoch 00188: val_loss did not improve from 0.41846
# Epoch 189/200
# 60000/60000 [==============================] - 32s 529us/step - loss: 0.0722 - accuracy: 1.0000 - val_loss: 1.2638 - val_accuracy: 0.8882
#
# Epoch 00189: val_loss did not improve from 0.41846
# Epoch 190/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0721 - accuracy: 1.0000 - val_loss: 1.2633 - val_accuracy: 0.8889
#
# Epoch 00190: val_loss did not improve from 0.41846
# Epoch 191/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0720 - accuracy: 1.0000 - val_loss: 1.2640 - val_accuracy: 0.8886
#
# Epoch 00191: val_loss did not improve from 0.41846
# Epoch 192/200
# 60000/60000 [==============================] - 32s 526us/step - loss: 0.0720 - accuracy: 1.0000 - val_loss: 1.2647 - val_accuracy: 0.8888
#
# Epoch 00192: val_loss did not improve from 0.41846
# Epoch 193/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0719 - accuracy: 1.0000 - val_loss: 1.2658 - val_accuracy: 0.8887
#
# Epoch 00193: val_loss did not improve from 0.41846
# Epoch 194/200
# 60000/60000 [==============================] - 32s 526us/step - loss: 0.0718 - accuracy: 1.0000 - val_loss: 1.2612 - val_accuracy: 0.8889
#
# Epoch 00194: val_loss did not improve from 0.41846
# Epoch 195/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0717 - accuracy: 1.0000 - val_loss: 1.2609 - val_accuracy: 0.8893
#
# Epoch 00195: val_loss did not improve from 0.41846
# Epoch 196/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.0717 - accuracy: 1.0000 - val_loss: 1.2667 - val_accuracy: 0.8888
#
# Epoch 00196: val_loss did not improve from 0.41846
# Epoch 197/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 1.2711 - val_accuracy: 0.8884
#
# Epoch 00197: val_loss did not improve from 0.41846
# Epoch 198/200
# 60000/60000 [==============================] - 32s 531us/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 1.2702 - val_accuracy: 0.8887
#
# Epoch 00198: val_loss did not improve from 0.41846
# Epoch 199/200
# 60000/60000 [==============================] - 31s 525us/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 1.2708 - val_accuracy: 0.8881
#
# Epoch 00199: val_loss did not improve from 0.41846
# Epoch 200/200
# 60000/60000 [==============================] - 32s 528us/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 1.2671 - val_accuracy: 0.8887
#
# Epoch 00200: val_loss did not improve from 0.41846

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 3s 330us/step
# Test loss: 1.2670959808349609
# Test accuracy: 0.888700008392334

# %%
model.save("ResNet18_Fashion_MNIST_Gaussian_Filter4.h5")

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# Iterate over layers
plot_filt=0
n_pad=15
layer_counter=0
for layer in model.layers:
	  # check for convolutional layer
    if 'conv' in layer.name:
        # if filters are 3x3 or larger:
        if layer.kernel.shape[0]>=3 and layer.kernel.shape[1]>=3:
            layer_counter+=1
            list_f_response=np.zeros(layer.kernel.shape[-2]*layer.kernel.shape[-1])
            # summarize kernel shape
            print(layer_counter,layer.name,layer.kernel.shape)
            filter_counter=0
            # Iterate over every 3x3 filter in this layer
            for in_ch in range(layer.kernel.shape[-2]):
                for out_ch in range(layer.kernel.shape[-1]):
                    # pad and fft the filters
                    p_filter=layer.kernel[:,:,in_ch,out_ch]
                    filter_pad=np.pad(p_filter,pad_width=n_pad,mode='constant',constant_values=0)
                    filter_fft=np.fft.fftshift(np.abs(np.fft.fft2(filter_pad))**2)
                    filter_fft=filter_fft/np.sum(filter_fft)
                    # plot some fft examples
                    if filter_counter<plot_filt:
                        plt.imshow(filter_fft)
                        plt.colorbar()
                        plt.pause(1)
                    
                    # get x and y axis to quantify HP/LP structure
                    f_axis_0=np.arange(filter_fft.shape[0])
                    f_axis_0[f_axis_0>np.floor(filter_fft.shape[0]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[0]/2))+1)
                    f_axis_0=np.fft.fftshift(f_axis_0)
                    f_axis_1=np.arange(filter_fft.shape[1])
                    f_axis_1[f_axis_1>np.floor(filter_fft.shape[1]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[1]/2))+1)
                    f_axis_1=np.fft.fftshift(f_axis_1)

                    Y,X=np.meshgrid(f_axis_0,f_axis_1)
                    euc_dist=np.sqrt(X**2+Y**2)
                    mean_f_response=np.mean(euc_dist*filter_fft)
                    list_f_response[filter_counter]=mean_f_response

                    filter_counter+=1
            hist,bins=np.histogram(list_f_response,bins=100)
            plt.plot(hist)
            plt.savefig("fig_g4"+layer.name+".png")
            plt.pause(1)
# Out:
# 1 conv2d_1 (7, 7, 1, 64)
# 2 conv2d_2 (3, 3, 64, 64)
# 3 conv2d_3 (3, 3, 64, 64)
# 4 conv2d_4 (3, 3, 64, 64)
# 5 conv2d_5 (3, 3, 64, 64)
# 6 conv2d_6 (3, 3, 64, 128)
# 7 conv2d_7 (3, 3, 128, 128)
# 8 conv2d_9 (3, 3, 128, 128)
# 9 conv2d_10 (3, 3, 128, 128)
# 10 conv2d_11 (3, 3, 128, 256)
# 11 conv2d_12 (3, 3, 256, 256)
# 12 conv2d_14 (3, 3, 256, 256)
# 13 conv2d_15 (3, 3, 256, 256)
# 14 conv2d_16 (3, 3, 256, 512)
# 15 conv2d_17 (3, 3, 512, 512)
# 16 conv2d_19 (3, 3, 512, 512)
# 17 conv2d_20 (3, 3, 512, 512)
