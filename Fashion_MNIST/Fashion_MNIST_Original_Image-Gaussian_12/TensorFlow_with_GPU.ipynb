# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import MaxPooling2D, AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# example of loading the fashion mnist dataset
from matplotlib import pyplot
from keras.datasets import fashion_mnist
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (X_train.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (X_test.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
from scipy.ndimage import gaussian_filter
io=[]


# Gaussian =gaussian_filter(X_train[i], sigma=12)
# z1=X_train[i]-Gaussian
# io.append(z1)
# io=np.array(io)
# print(io.shape)

for i in range(60000):
  Gaussian =gaussian_filter(X_train[i], sigma=12)
  z=X_train[i]-Gaussian
  io.append(z)
io=np.array(io)
print(io.shape)
op=[]
for j in range(10000):
  Gaussian =gaussian_filter(X_test[j], sigma=12)
  z1=X_test[j]-Gaussian
  op.append(z1)
op=np.array(op)
print(op.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
#Summary after Gaussian filter
print('Train: X=%s, y=%s' % (io.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (op.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(io[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
#Defining constants
epochs = 200
batch_size = 100
data_augmentation = False
img_size = 28

num_classes = 10
num_filters = 64
num_blocks = 4
num_sub_blocks = 2
use_max_pool = False

# %%
x_train = io.reshape(io.shape[0],img_size,img_size,1)
x_test = op.reshape(op.shape[0],img_size,img_size,1)
input_size = (img_size, img_size,1)
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('Y_train shape:', Y_train.shape)

#Converting labels to one-hot vectors
y_train = keras.utils.to_categorical(Y_train, num_classes)
y_test = keras.utils.to_categorical(Y_test,num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Y_train shape: (60000,)

# %%
#Creating model based on ResNet published archietecture
inputs = Input(shape=input_size)
x = Conv2D(num_filters, padding='same', 
           kernel_initializer='he_normal', 
           kernel_size=7, strides=2,
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

#Check by applying max pooling later (setting it false as size of image is small i.e. 28x28)
if use_max_pool:
    x = MaxPooling2D(pool_size=3,padding='same', strides=2)(x)
    num_blocks =3
#Creating Conv base stack 

# Instantiate convolutional base (stack of blocks).
for i in range(num_blocks):
    for j in range(num_sub_blocks):
        strides = 1
        is_first_layer_but_not_first_block = j == 0 and i > 0
        if is_first_layer_but_not_first_block:
            strides = 2
        #Creating residual mapping using y
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   strides=strides,
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if is_first_layer_but_not_first_block:
            x = Conv2D(num_filters,
                       kernel_size=1,
                       padding='same',
                       strides=2,
                       kernel_initializer='he_normal',
                       kernel_regularizer=l2(1e-4))(x)
        #Adding back residual mapping
        x = keras.layers.add([x, y])
        x = Activation('relu')(x)

    num_filters = 2 * num_filters

# Add classifier on top.
x = AveragePooling2D()(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                activation='softmax',
                kernel_initializer='he_normal')(y)

# Instantiate and compile model.
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 14, 14, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 14, 14, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 64)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 64)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 128)    8320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 7, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 128)    0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 128)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 128)    0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 256)    295168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 256)    33024       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 256)    0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 512)    1180160     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 512)    131584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 512)    0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 512)    0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 512)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,186,186
# Trainable params: 11,178,378
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'saved_model')
model_name = 'fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir,model_name)
print(filepath)
# Prepare callbacks for model saving and for learning rate decaying.
checkpoint = ModelCheckpoint(filepath=filepath,
                             verbose=1,
                             save_best_only=True)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer]
# Out:
# /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5

# %%
if not data_augmentation:
    print('Using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
# Out:
# Using data augmentation.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 39s 644us/step - loss: 1.3193 - accuracy: 0.8104 - val_loss: 1.0346 - val_accuracy: 0.8465
#
# Epoch 00001: val_loss improved from inf to 1.03460, saving model to /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5
# Epoch 2/200
# 60000/60000 [==============================] - 28s 474us/step - loss: 0.8593 - accuracy: 0.8740 - val_loss: 0.8722 - val_accuracy: 0.8447
#
# Epoch 00002: val_loss improved from 1.03460 to 0.87215, saving model to /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5
# Epoch 3/200
# 60000/60000 [==============================] - 28s 472us/step - loss: 0.6790 - accuracy: 0.8912 - val_loss: 0.8827 - val_accuracy: 0.8179
#
# Epoch 00003: val_loss did not improve from 0.87215
# Epoch 4/200
# 60000/60000 [==============================] - 28s 470us/step - loss: 0.5827 - accuracy: 0.9008 - val_loss: 0.6721 - val_accuracy: 0.8607
#
# Epoch 00004: val_loss improved from 0.87215 to 0.67213, saving model to /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5
# Epoch 5/200
# 60000/60000 [==============================] - 28s 470us/step - loss: 0.5208 - accuracy: 0.9115 - val_loss: 0.6683 - val_accuracy: 0.8629
#
# Epoch 00005: val_loss improved from 0.67213 to 0.66829, saving model to /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5
# Epoch 6/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.4854 - accuracy: 0.9173 - val_loss: 0.7011 - val_accuracy: 0.8532
#
# Epoch 00006: val_loss did not improve from 0.66829
# Epoch 7/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.4600 - accuracy: 0.9238 - val_loss: 0.6364 - val_accuracy: 0.8672
#
# Epoch 00007: val_loss improved from 0.66829 to 0.63640, saving model to /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5
# Epoch 8/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.4360 - accuracy: 0.9306 - val_loss: 0.6380 - val_accuracy: 0.8612
#
# Epoch 00008: val_loss did not improve from 0.63640
# Epoch 9/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.4136 - accuracy: 0.9384 - val_loss: 0.6699 - val_accuracy: 0.8605
#
# Epoch 00009: val_loss did not improve from 0.63640
# Epoch 10/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.4011 - accuracy: 0.9430 - val_loss: 0.6306 - val_accuracy: 0.8714
#
# Epoch 00010: val_loss improved from 0.63640 to 0.63056, saving model to /content/saved_model/fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5
# Epoch 11/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.3818 - accuracy: 0.9483 - val_loss: 0.6470 - val_accuracy: 0.8671
#
# Epoch 00011: val_loss did not improve from 0.63056
# Epoch 12/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.3723 - accuracy: 0.9527 - val_loss: 0.6468 - val_accuracy: 0.8713
#
# Epoch 00012: val_loss did not improve from 0.63056
# Epoch 13/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.3647 - accuracy: 0.9595 - val_loss: 0.6513 - val_accuracy: 0.8692
#
# Epoch 00013: val_loss did not improve from 0.63056
# Epoch 14/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.3473 - accuracy: 0.9625 - val_loss: 0.6574 - val_accuracy: 0.8705
#
# Epoch 00014: val_loss did not improve from 0.63056
# Epoch 15/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.3298 - accuracy: 0.9649 - val_loss: 0.7138 - val_accuracy: 0.8742
#
# Epoch 00015: val_loss did not improve from 0.63056
# Epoch 16/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.2501 - accuracy: 0.9905 - val_loss: 0.7223 - val_accuracy: 0.8856
#
# Epoch 00016: val_loss did not improve from 0.63056
# Epoch 17/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.2103 - accuracy: 0.9978 - val_loss: 0.7954 - val_accuracy: 0.8870
#
# Epoch 00017: val_loss did not improve from 0.63056
# Epoch 18/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.1964 - accuracy: 0.9969 - val_loss: 0.7908 - val_accuracy: 0.8865
#
# Epoch 00018: val_loss did not improve from 0.63056
# Epoch 19/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.1899 - accuracy: 0.9954 - val_loss: 0.7977 - val_accuracy: 0.8853
#
# Epoch 00019: val_loss did not improve from 0.63056
# Epoch 20/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.1844 - accuracy: 0.9942 - val_loss: 0.6922 - val_accuracy: 0.8846
#
# Epoch 00020: val_loss did not improve from 0.63056
# Epoch 21/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.1663 - accuracy: 0.9986 - val_loss: 0.7707 - val_accuracy: 0.8928
#
# Epoch 00021: val_loss did not improve from 0.63056
# Epoch 22/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.1561 - accuracy: 0.9999 - val_loss: 0.8443 - val_accuracy: 0.8924
#
# Epoch 00022: val_loss did not improve from 0.63056
# Epoch 23/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.1489 - accuracy: 1.0000 - val_loss: 0.8963 - val_accuracy: 0.8911
#
# Epoch 00023: val_loss did not improve from 0.63056
# Epoch 24/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.1413 - accuracy: 1.0000 - val_loss: 2.1264 - val_accuracy: 0.7367
#
# Epoch 00024: val_loss did not improve from 0.63056
# Epoch 25/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.1363 - accuracy: 0.9995 - val_loss: 0.8656 - val_accuracy: 0.8888
#
# Epoch 00025: val_loss did not improve from 0.63056
# Epoch 26/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.1318 - accuracy: 0.9997 - val_loss: 0.8497 - val_accuracy: 0.8923
#
# Epoch 00026: val_loss did not improve from 0.63056
# Epoch 27/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.1276 - accuracy: 1.0000 - val_loss: 0.8853 - val_accuracy: 0.8934
#
# Epoch 00027: val_loss did not improve from 0.63056
# Epoch 28/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.1243 - accuracy: 1.0000 - val_loss: 0.9672 - val_accuracy: 0.8929
#
# Epoch 00028: val_loss did not improve from 0.63056
# Epoch 29/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.1204 - accuracy: 1.0000 - val_loss: 1.0348 - val_accuracy: 0.8927
#
# Epoch 00029: val_loss did not improve from 0.63056
# Epoch 30/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.1160 - accuracy: 1.0000 - val_loss: 0.9486 - val_accuracy: 0.8928
#
# Epoch 00030: val_loss did not improve from 0.63056
# Epoch 31/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.1126 - accuracy: 1.0000 - val_loss: 1.0233 - val_accuracy: 0.8921
#
# Epoch 00031: val_loss did not improve from 0.63056
# Epoch 32/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.1105 - accuracy: 1.0000 - val_loss: 1.0595 - val_accuracy: 0.8925
#
# Epoch 00032: val_loss did not improve from 0.63056
# Epoch 33/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.1080 - accuracy: 1.0000 - val_loss: 1.0929 - val_accuracy: 0.8924
#
# Epoch 00033: val_loss did not improve from 0.63056
# Epoch 34/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.1052 - accuracy: 1.0000 - val_loss: 1.0811 - val_accuracy: 0.8915
#
# Epoch 00034: val_loss did not improve from 0.63056
# Epoch 35/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.1024 - accuracy: 1.0000 - val_loss: 1.0391 - val_accuracy: 0.8923
#
# Epoch 00035: val_loss did not improve from 0.63056
# Epoch 36/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.1007 - accuracy: 1.0000 - val_loss: 1.0871 - val_accuracy: 0.8917
#
# Epoch 00036: val_loss did not improve from 0.63056
# Epoch 37/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0998 - accuracy: 1.0000 - val_loss: 1.1234 - val_accuracy: 0.8913
#
# Epoch 00037: val_loss did not improve from 0.63056
# Epoch 38/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0987 - accuracy: 1.0000 - val_loss: 1.1298 - val_accuracy: 0.8921
#
# Epoch 00038: val_loss did not improve from 0.63056
# Epoch 39/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0978 - accuracy: 1.0000 - val_loss: 1.1003 - val_accuracy: 0.8910
#
# Epoch 00039: val_loss did not improve from 0.63056
# Epoch 40/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 1.1318 - val_accuracy: 0.8913
#
# Epoch 00040: val_loss did not improve from 0.63056
# Epoch 41/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0965 - accuracy: 1.0000 - val_loss: 1.1477 - val_accuracy: 0.8922
#
# Epoch 00041: val_loss did not improve from 0.63056
# Epoch 42/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0961 - accuracy: 1.0000 - val_loss: 1.1614 - val_accuracy: 0.8926
#
# Epoch 00042: val_loss did not improve from 0.63056
# Epoch 43/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 1.1719 - val_accuracy: 0.8915
#
# Epoch 00043: val_loss did not improve from 0.63056
# Epoch 44/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0953 - accuracy: 1.0000 - val_loss: 1.1835 - val_accuracy: 0.8920
#
# Epoch 00044: val_loss did not improve from 0.63056
# Epoch 45/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0949 - accuracy: 1.0000 - val_loss: 1.2010 - val_accuracy: 0.8921
#
# Epoch 00045: val_loss did not improve from 0.63056
# Epoch 46/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0945 - accuracy: 1.0000 - val_loss: 1.2044 - val_accuracy: 0.8924
#
# Epoch 00046: val_loss did not improve from 0.63056
# Epoch 47/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0943 - accuracy: 1.0000 - val_loss: 1.2075 - val_accuracy: 0.8928
#
# Epoch 00047: val_loss did not improve from 0.63056
# Epoch 48/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0941 - accuracy: 1.0000 - val_loss: 1.2060 - val_accuracy: 0.8929
#
# Epoch 00048: val_loss did not improve from 0.63056
# Epoch 49/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0939 - accuracy: 1.0000 - val_loss: 1.1969 - val_accuracy: 0.8915
#
# Epoch 00049: val_loss did not improve from 0.63056
# Epoch 50/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0938 - accuracy: 1.0000 - val_loss: 1.2015 - val_accuracy: 0.8915
#
# Epoch 00050: val_loss did not improve from 0.63056
# Epoch 51/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 1.2043 - val_accuracy: 0.8916
#
# Epoch 00051: val_loss did not improve from 0.63056
# Epoch 52/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0934 - accuracy: 1.0000 - val_loss: 1.2104 - val_accuracy: 0.8914
#
# Epoch 00052: val_loss did not improve from 0.63056
# Epoch 53/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0932 - accuracy: 1.0000 - val_loss: 1.2110 - val_accuracy: 0.8924
#
# Epoch 00053: val_loss did not improve from 0.63056
# Epoch 54/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.0930 - accuracy: 1.0000 - val_loss: 1.2107 - val_accuracy: 0.8922
#
# Epoch 00054: val_loss did not improve from 0.63056
# Epoch 55/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0929 - accuracy: 1.0000 - val_loss: 1.2155 - val_accuracy: 0.8924
#
# Epoch 00055: val_loss did not improve from 0.63056
# Epoch 56/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0927 - accuracy: 1.0000 - val_loss: 1.2169 - val_accuracy: 0.8914
#
# Epoch 00056: val_loss did not improve from 0.63056
# Epoch 57/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 1.2214 - val_accuracy: 0.8920
#
# Epoch 00057: val_loss did not improve from 0.63056
# Epoch 58/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0922 - accuracy: 1.0000 - val_loss: 1.2234 - val_accuracy: 0.8912
#
# Epoch 00058: val_loss did not improve from 0.63056
# Epoch 59/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 1.2240 - val_accuracy: 0.8914
#
# Epoch 00059: val_loss did not improve from 0.63056
# Epoch 60/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0917 - accuracy: 1.0000 - val_loss: 1.2283 - val_accuracy: 0.8917
#
# Epoch 00060: val_loss did not improve from 0.63056
# Epoch 61/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 1.2283 - val_accuracy: 0.8920
#
# Epoch 00061: val_loss did not improve from 0.63056
# Epoch 62/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0911 - accuracy: 1.0000 - val_loss: 1.2382 - val_accuracy: 0.8918
#
# Epoch 00062: val_loss did not improve from 0.63056
# Epoch 63/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0908 - accuracy: 1.0000 - val_loss: 1.2419 - val_accuracy: 0.8922
#
# Epoch 00063: val_loss did not improve from 0.63056
# Epoch 64/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0905 - accuracy: 1.0000 - val_loss: 1.2475 - val_accuracy: 0.8923
#
# Epoch 00064: val_loss did not improve from 0.63056
# Epoch 65/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0900 - accuracy: 1.0000 - val_loss: 1.2547 - val_accuracy: 0.8923
#
# Epoch 00065: val_loss did not improve from 0.63056
# Epoch 66/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0896 - accuracy: 1.0000 - val_loss: 1.2667 - val_accuracy: 0.8926
#
# Epoch 00066: val_loss did not improve from 0.63056
# Epoch 67/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0891 - accuracy: 1.0000 - val_loss: 1.2700 - val_accuracy: 0.8918
#
# Epoch 00067: val_loss did not improve from 0.63056
# Epoch 68/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 1.2775 - val_accuracy: 0.8921
#
# Epoch 00068: val_loss did not improve from 0.63056
# Epoch 69/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0883 - accuracy: 1.0000 - val_loss: 1.2764 - val_accuracy: 0.8922
#
# Epoch 00069: val_loss did not improve from 0.63056
# Epoch 70/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0879 - accuracy: 1.0000 - val_loss: 1.2736 - val_accuracy: 0.8926
#
# Epoch 00070: val_loss did not improve from 0.63056
# Epoch 71/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0875 - accuracy: 1.0000 - val_loss: 1.2763 - val_accuracy: 0.8927
#
# Epoch 00071: val_loss did not improve from 0.63056
# Epoch 72/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0871 - accuracy: 1.0000 - val_loss: 1.2735 - val_accuracy: 0.8928
#
# Epoch 00072: val_loss did not improve from 0.63056
# Epoch 73/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0867 - accuracy: 1.0000 - val_loss: 1.2803 - val_accuracy: 0.8929
#
# Epoch 00073: val_loss did not improve from 0.63056
# Epoch 74/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0862 - accuracy: 1.0000 - val_loss: 1.2733 - val_accuracy: 0.8920
#
# Epoch 00074: val_loss did not improve from 0.63056
# Epoch 75/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0858 - accuracy: 1.0000 - val_loss: 1.2764 - val_accuracy: 0.8915
#
# Epoch 00075: val_loss did not improve from 0.63056
# Epoch 76/200
# 60000/60000 [==============================] - 28s 470us/step - loss: 0.0855 - accuracy: 1.0000 - val_loss: 1.2747 - val_accuracy: 0.8924
#
# Epoch 00076: val_loss did not improve from 0.63056
# Epoch 77/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 1.2744 - val_accuracy: 0.8924
#
# Epoch 00077: val_loss did not improve from 0.63056
# Epoch 78/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0851 - accuracy: 1.0000 - val_loss: 1.2808 - val_accuracy: 0.8921
#
# Epoch 00078: val_loss did not improve from 0.63056
# Epoch 79/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0848 - accuracy: 1.0000 - val_loss: 1.2837 - val_accuracy: 0.8925
#
# Epoch 00079: val_loss did not improve from 0.63056
# Epoch 80/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0845 - accuracy: 1.0000 - val_loss: 1.2900 - val_accuracy: 0.8920
#
# Epoch 00080: val_loss did not improve from 0.63056
# Epoch 81/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0843 - accuracy: 1.0000 - val_loss: 1.2852 - val_accuracy: 0.8921
#
# Epoch 00081: val_loss did not improve from 0.63056
# Epoch 82/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0840 - accuracy: 1.0000 - val_loss: 1.2858 - val_accuracy: 0.8916
#
# Epoch 00082: val_loss did not improve from 0.63056
# Epoch 83/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 1.2877 - val_accuracy: 0.8922
#
# Epoch 00083: val_loss did not improve from 0.63056
# Epoch 84/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0836 - accuracy: 1.0000 - val_loss: 1.2885 - val_accuracy: 0.8920
#
# Epoch 00084: val_loss did not improve from 0.63056
# Epoch 85/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0834 - accuracy: 1.0000 - val_loss: 1.2878 - val_accuracy: 0.8922
#
# Epoch 00085: val_loss did not improve from 0.63056
# Epoch 86/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 1.2910 - val_accuracy: 0.8923
#
# Epoch 00086: val_loss did not improve from 0.63056
# Epoch 87/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0829 - accuracy: 1.0000 - val_loss: 1.2941 - val_accuracy: 0.8928
#
# Epoch 00087: val_loss did not improve from 0.63056
# Epoch 88/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 1.2985 - val_accuracy: 0.8925
#
# Epoch 00088: val_loss did not improve from 0.63056
# Epoch 89/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 1.2950 - val_accuracy: 0.8926
#
# Epoch 00089: val_loss did not improve from 0.63056
# Epoch 90/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0821 - accuracy: 1.0000 - val_loss: 1.2972 - val_accuracy: 0.8919
#
# Epoch 00090: val_loss did not improve from 0.63056
# Epoch 91/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 1.2770 - val_accuracy: 0.8930
#
# Epoch 00091: val_loss did not improve from 0.63056
# Epoch 92/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 1.2837 - val_accuracy: 0.8920
#
# Epoch 00092: val_loss did not improve from 0.63056
# Epoch 93/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 1.2884 - val_accuracy: 0.8925
#
# Epoch 00093: val_loss did not improve from 0.63056
# Epoch 94/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0812 - accuracy: 1.0000 - val_loss: 1.2902 - val_accuracy: 0.8931
#
# Epoch 00094: val_loss did not improve from 0.63056
# Epoch 95/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0809 - accuracy: 1.0000 - val_loss: 1.2827 - val_accuracy: 0.8916
#
# Epoch 00095: val_loss did not improve from 0.63056
# Epoch 96/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0805 - accuracy: 1.0000 - val_loss: 1.2912 - val_accuracy: 0.8916
#
# Epoch 00096: val_loss did not improve from 0.63056
# Epoch 97/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0802 - accuracy: 1.0000 - val_loss: 1.2856 - val_accuracy: 0.8915
#
# Epoch 00097: val_loss did not improve from 0.63056
# Epoch 98/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0800 - accuracy: 1.0000 - val_loss: 1.2861 - val_accuracy: 0.8923
#
# Epoch 00098: val_loss did not improve from 0.63056
# Epoch 99/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 1.2936 - val_accuracy: 0.8923
#
# Epoch 00099: val_loss did not improve from 0.63056
# Epoch 100/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0795 - accuracy: 1.0000 - val_loss: 1.2927 - val_accuracy: 0.8921
#
# Epoch 00100: val_loss did not improve from 0.63056
# Epoch 101/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0793 - accuracy: 1.0000 - val_loss: 1.2983 - val_accuracy: 0.8919
#
# Epoch 00101: val_loss did not improve from 0.63056
# Epoch 102/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 1.2992 - val_accuracy: 0.8923
#
# Epoch 00102: val_loss did not improve from 0.63056
# Epoch 103/200
# 60000/60000 [==============================] - 28s 471us/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 1.2967 - val_accuracy: 0.8920
#
# Epoch 00103: val_loss did not improve from 0.63056
# Epoch 104/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.0788 - accuracy: 1.0000 - val_loss: 1.2973 - val_accuracy: 0.8918
#
# Epoch 00104: val_loss did not improve from 0.63056
# Epoch 105/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0785 - accuracy: 1.0000 - val_loss: 1.2967 - val_accuracy: 0.8921
#
# Epoch 00105: val_loss did not improve from 0.63056
# Epoch 106/200
# 60000/60000 [==============================] - 29s 479us/step - loss: 0.0784 - accuracy: 1.0000 - val_loss: 1.2958 - val_accuracy: 0.8926
#
# Epoch 00106: val_loss did not improve from 0.63056
# Epoch 107/200
# 60000/60000 [==============================] - 28s 470us/step - loss: 0.0782 - accuracy: 1.0000 - val_loss: 1.2942 - val_accuracy: 0.8929
#
# Epoch 00107: val_loss did not improve from 0.63056
# Epoch 108/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.0780 - accuracy: 1.0000 - val_loss: 1.2978 - val_accuracy: 0.8926
#
# Epoch 00108: val_loss did not improve from 0.63056
# Epoch 109/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 1.2984 - val_accuracy: 0.8928
#
# Epoch 00109: val_loss did not improve from 0.63056
# Epoch 110/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 1.2957 - val_accuracy: 0.8922
#
# Epoch 00110: val_loss did not improve from 0.63056
# Epoch 111/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0772 - accuracy: 1.0000 - val_loss: 1.2957 - val_accuracy: 0.8925
#
# Epoch 00111: val_loss did not improve from 0.63056
# Epoch 112/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 1.2961 - val_accuracy: 0.8919
#
# Epoch 00112: val_loss did not improve from 0.63056
# Epoch 113/200
# 60000/60000 [==============================] - 28s 470us/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 1.2987 - val_accuracy: 0.8924
#
# Epoch 00113: val_loss did not improve from 0.63056
# Epoch 114/200
# 60000/60000 [==============================] - 28s 471us/step - loss: 0.0765 - accuracy: 1.0000 - val_loss: 1.2947 - val_accuracy: 0.8925
#
# Epoch 00114: val_loss did not improve from 0.63056
# Epoch 115/200
# 60000/60000 [==============================] - 28s 471us/step - loss: 0.0763 - accuracy: 1.0000 - val_loss: 1.2941 - val_accuracy: 0.8928
#
# Epoch 00115: val_loss did not improve from 0.63056
# Epoch 116/200
# 60000/60000 [==============================] - 28s 473us/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 1.2927 - val_accuracy: 0.8917
#
# Epoch 00116: val_loss did not improve from 0.63056
# Epoch 117/200
# 60000/60000 [==============================] - 28s 475us/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 1.2921 - val_accuracy: 0.8931
#
# Epoch 00117: val_loss did not improve from 0.63056
# Epoch 118/200
# 60000/60000 [==============================] - 28s 475us/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 1.2971 - val_accuracy: 0.8931
#
# Epoch 00118: val_loss did not improve from 0.63056
# Epoch 119/200
# 60000/60000 [==============================] - 29s 477us/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 1.2974 - val_accuracy: 0.8926
#
# Epoch 00119: val_loss did not improve from 0.63056
# Epoch 120/200
# 60000/60000 [==============================] - 29s 478us/step - loss: 0.0749 - accuracy: 1.0000 - val_loss: 1.2942 - val_accuracy: 0.8922
#
# Epoch 00120: val_loss did not improve from 0.63056
# Epoch 121/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 1.2988 - val_accuracy: 0.8921
#
# Epoch 00121: val_loss did not improve from 0.63056
# Epoch 122/200
# 60000/60000 [==============================] - 28s 472us/step - loss: 0.0744 - accuracy: 1.0000 - val_loss: 1.3007 - val_accuracy: 0.8918
#
# Epoch 00122: val_loss did not improve from 0.63056
# Epoch 123/200
# 60000/60000 [==============================] - 29s 475us/step - loss: 0.0742 - accuracy: 1.0000 - val_loss: 1.2989 - val_accuracy: 0.8918
#
# Epoch 00123: val_loss did not improve from 0.63056
# Epoch 124/200
# 60000/60000 [==============================] - 28s 474us/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 1.2880 - val_accuracy: 0.8930
#
# Epoch 00124: val_loss did not improve from 0.63056
# Epoch 125/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 1.2875 - val_accuracy: 0.8917
#
# Epoch 00125: val_loss did not improve from 0.63056
# Epoch 126/200
# 60000/60000 [==============================] - 28s 475us/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 1.2881 - val_accuracy: 0.8921
#
# Epoch 00126: val_loss did not improve from 0.63056
# Epoch 127/200
# 60000/60000 [==============================] - 28s 475us/step - loss: 0.0737 - accuracy: 1.0000 - val_loss: 1.2895 - val_accuracy: 0.8927
#
# Epoch 00127: val_loss did not improve from 0.63056
# Epoch 128/200
# 60000/60000 [==============================] - 29s 477us/step - loss: 0.0736 - accuracy: 1.0000 - val_loss: 1.2841 - val_accuracy: 0.8930
#
# Epoch 00128: val_loss did not improve from 0.63056
# Epoch 129/200
# 60000/60000 [==============================] - 29s 477us/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 1.2734 - val_accuracy: 0.8926
#
# Epoch 00129: val_loss did not improve from 0.63056
# Epoch 130/200
# 60000/60000 [==============================] - 29s 477us/step - loss: 0.0733 - accuracy: 1.0000 - val_loss: 1.2715 - val_accuracy: 0.8934
#
# Epoch 00130: val_loss did not improve from 0.63056
# Epoch 131/200
# 60000/60000 [==============================] - 29s 478us/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 1.2838 - val_accuracy: 0.8917
#
# Epoch 00131: val_loss did not improve from 0.63056
# Epoch 132/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0730 - accuracy: 1.0000 - val_loss: 1.2798 - val_accuracy: 0.8922
#
# Epoch 00132: val_loss did not improve from 0.63056
# Epoch 133/200
# 60000/60000 [==============================] - 29s 478us/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 1.2802 - val_accuracy: 0.8922
#
# Epoch 00133: val_loss did not improve from 0.63056
# Epoch 134/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 1.2819 - val_accuracy: 0.8910
#
# Epoch 00134: val_loss did not improve from 0.63056
# Epoch 135/200
# 60000/60000 [==============================] - 28s 475us/step - loss: 0.0726 - accuracy: 1.0000 - val_loss: 1.2874 - val_accuracy: 0.8919
#
# Epoch 00135: val_loss did not improve from 0.63056
# Epoch 136/200
# 60000/60000 [==============================] - 29s 477us/step - loss: 0.0724 - accuracy: 1.0000 - val_loss: 1.2857 - val_accuracy: 0.8938
#
# Epoch 00136: val_loss did not improve from 0.63056
# Epoch 137/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 0.0722 - accuracy: 1.0000 - val_loss: 1.2869 - val_accuracy: 0.8925
#
# Epoch 00137: val_loss did not improve from 0.63056
# Epoch 138/200
# 60000/60000 [==============================] - 29s 478us/step - loss: 0.0720 - accuracy: 1.0000 - val_loss: 1.2838 - val_accuracy: 0.8917
#
# Epoch 00138: val_loss did not improve from 0.63056
# Epoch 139/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 0.0718 - accuracy: 1.0000 - val_loss: 1.2879 - val_accuracy: 0.8915
#
# Epoch 00139: val_loss did not improve from 0.63056
# Epoch 140/200
# 60000/60000 [==============================] - 29s 478us/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 1.2857 - val_accuracy: 0.8922
#
# Epoch 00140: val_loss did not improve from 0.63056
# Epoch 141/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 1.2867 - val_accuracy: 0.8914
#
# Epoch 00141: val_loss did not improve from 0.63056
# Epoch 142/200
# 60000/60000 [==============================] - 29s 479us/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 1.2904 - val_accuracy: 0.8918
#
# Epoch 00142: val_loss did not improve from 0.63056
# Epoch 143/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0709 - accuracy: 1.0000 - val_loss: 1.2873 - val_accuracy: 0.8924
#
# Epoch 00143: val_loss did not improve from 0.63056
# Epoch 144/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0708 - accuracy: 1.0000 - val_loss: 1.2855 - val_accuracy: 0.8928
#
# Epoch 00144: val_loss did not improve from 0.63056
# Epoch 145/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 1.2880 - val_accuracy: 0.8922
#
# Epoch 00145: val_loss did not improve from 0.63056
# Epoch 146/200
# 60000/60000 [==============================] - 29s 481us/step - loss: 0.0705 - accuracy: 1.0000 - val_loss: 1.2800 - val_accuracy: 0.8914
#
# Epoch 00146: val_loss did not improve from 0.63056
# Epoch 147/200
# 60000/60000 [==============================] - 29s 483us/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 1.2827 - val_accuracy: 0.8916
#
# Epoch 00147: val_loss did not improve from 0.63056
# Epoch 148/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0703 - accuracy: 1.0000 - val_loss: 1.2780 - val_accuracy: 0.8923
#
# Epoch 00148: val_loss did not improve from 0.63056
# Epoch 149/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0702 - accuracy: 1.0000 - val_loss: 1.2789 - val_accuracy: 0.8925
#
# Epoch 00149: val_loss did not improve from 0.63056
# Epoch 150/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 1.2754 - val_accuracy: 0.8922
#
# Epoch 00150: val_loss did not improve from 0.63056
# Epoch 151/200
# 60000/60000 [==============================] - 29s 484us/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 1.2805 - val_accuracy: 0.8921
#
# Epoch 00151: val_loss did not improve from 0.63056
# Epoch 152/200
# 60000/60000 [==============================] - 29s 483us/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 1.2772 - val_accuracy: 0.8928
#
# Epoch 00152: val_loss did not improve from 0.63056
# Epoch 153/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0697 - accuracy: 1.0000 - val_loss: 1.2767 - val_accuracy: 0.8931
#
# Epoch 00153: val_loss did not improve from 0.63056
# Epoch 154/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 1.2847 - val_accuracy: 0.8914
#
# Epoch 00154: val_loss did not improve from 0.63056
# Epoch 155/200
# 60000/60000 [==============================] - 29s 483us/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 1.2816 - val_accuracy: 0.8908
#
# Epoch 00155: val_loss did not improve from 0.63056
# Epoch 156/200
# 60000/60000 [==============================] - 29s 484us/step - loss: 0.0694 - accuracy: 1.0000 - val_loss: 1.2746 - val_accuracy: 0.8914
#
# Epoch 00156: val_loss did not improve from 0.63056
# Epoch 157/200
# 60000/60000 [==============================] - 29s 484us/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 1.2679 - val_accuracy: 0.8909
#
# Epoch 00157: val_loss did not improve from 0.63056
# Epoch 158/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 1.2798 - val_accuracy: 0.8917
#
# Epoch 00158: val_loss did not improve from 0.63056
# Epoch 159/200
# 60000/60000 [==============================] - 29s 484us/step - loss: 0.0691 - accuracy: 1.0000 - val_loss: 1.2751 - val_accuracy: 0.8922
#
# Epoch 00159: val_loss did not improve from 0.63056
# Epoch 160/200
# 60000/60000 [==============================] - 29s 481us/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 1.2737 - val_accuracy: 0.8921
#
# Epoch 00160: val_loss did not improve from 0.63056
# Epoch 161/200
# 60000/60000 [==============================] - 29s 484us/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.8911
#
# Epoch 00161: val_loss did not improve from 0.63056
# Epoch 162/200
# 60000/60000 [==============================] - 29s 482us/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 1.2681 - val_accuracy: 0.8920
#
# Epoch 00162: val_loss did not improve from 0.63056
# Epoch 163/200
# 60000/60000 [==============================] - 29s 483us/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.8927
#
# Epoch 00163: val_loss did not improve from 0.63056
# Epoch 164/200
# 60000/60000 [==============================] - 29s 487us/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 1.2680 - val_accuracy: 0.8926
#
# Epoch 00164: val_loss did not improve from 0.63056
# Epoch 165/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0682 - accuracy: 1.0000 - val_loss: 1.2713 - val_accuracy: 0.8916
#
# Epoch 00165: val_loss did not improve from 0.63056
# Epoch 166/200
# 60000/60000 [==============================] - 29s 484us/step - loss: 0.0681 - accuracy: 1.0000 - val_loss: 1.2748 - val_accuracy: 0.8933
#
# Epoch 00166: val_loss did not improve from 0.63056
# Epoch 167/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0680 - accuracy: 1.0000 - val_loss: 1.2753 - val_accuracy: 0.8924
#
# Epoch 00167: val_loss did not improve from 0.63056
# Epoch 168/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 1.2749 - val_accuracy: 0.8929
#
# Epoch 00168: val_loss did not improve from 0.63056
# Epoch 169/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 1.2786 - val_accuracy: 0.8928
#
# Epoch 00169: val_loss did not improve from 0.63056
# Epoch 170/200
# 60000/60000 [==============================] - 29s 488us/step - loss: 0.0676 - accuracy: 1.0000 - val_loss: 1.2727 - val_accuracy: 0.8924
#
# Epoch 00170: val_loss did not improve from 0.63056
# Epoch 171/200
# 60000/60000 [==============================] - 29s 487us/step - loss: 0.0675 - accuracy: 1.0000 - val_loss: 1.2723 - val_accuracy: 0.8924
#
# Epoch 00171: val_loss did not improve from 0.63056
# Epoch 172/200
# 60000/60000 [==============================] - 29s 488us/step - loss: 0.0673 - accuracy: 1.0000 - val_loss: 1.2796 - val_accuracy: 0.8913
#
# Epoch 00172: val_loss did not improve from 0.63056
# Epoch 173/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 1.2755 - val_accuracy: 0.8918
#
# Epoch 00173: val_loss did not improve from 0.63056
# Epoch 174/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0671 - accuracy: 1.0000 - val_loss: 1.2744 - val_accuracy: 0.8915
#
# Epoch 00174: val_loss did not improve from 0.63056
# Epoch 175/200
# 60000/60000 [==============================] - 29s 487us/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 1.2740 - val_accuracy: 0.8913
#
# Epoch 00175: val_loss did not improve from 0.63056
# Epoch 176/200
# 60000/60000 [==============================] - 29s 483us/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 1.2677 - val_accuracy: 0.8917
#
# Epoch 00176: val_loss did not improve from 0.63056
# Epoch 177/200
# 60000/60000 [==============================] - 29s 482us/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 1.2744 - val_accuracy: 0.8914
#
# Epoch 00177: val_loss did not improve from 0.63056
# Epoch 178/200
# 60000/60000 [==============================] - 29s 481us/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 1.2760 - val_accuracy: 0.8919
#
# Epoch 00178: val_loss did not improve from 0.63056
# Epoch 179/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0665 - accuracy: 1.0000 - val_loss: 1.2750 - val_accuracy: 0.8923
#
# Epoch 00179: val_loss did not improve from 0.63056
# Epoch 180/200
# 60000/60000 [==============================] - 29s 477us/step - loss: 0.0663 - accuracy: 1.0000 - val_loss: 1.2741 - val_accuracy: 0.8924
#
# Epoch 00180: val_loss did not improve from 0.63056
# Epoch 181/200
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0661 - accuracy: 1.0000 - val_loss: 1.2688 - val_accuracy: 0.8926
#
# Epoch 00181: val_loss did not improve from 0.63056
# Epoch 182/200
# 60000/60000 [==============================] - 29s 488us/step - loss: 0.0660 - accuracy: 1.0000 - val_loss: 1.2654 - val_accuracy: 0.8921
#
# Epoch 00182: val_loss did not improve from 0.63056
# Epoch 183/200
# 60000/60000 [==============================] - 29s 483us/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 1.2694 - val_accuracy: 0.8926
#
# Epoch 00183: val_loss did not improve from 0.63056
# Epoch 184/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 1.2585 - val_accuracy: 0.8920
#
# Epoch 00184: val_loss did not improve from 0.63056
# Epoch 185/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 1.2560 - val_accuracy: 0.8926
#
# Epoch 00185: val_loss did not improve from 0.63056
# Epoch 186/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0654 - accuracy: 1.0000 - val_loss: 1.2657 - val_accuracy: 0.8916
#
# Epoch 00186: val_loss did not improve from 0.63056
# Epoch 187/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.0653 - accuracy: 1.0000 - val_loss: 1.2612 - val_accuracy: 0.8931
#
# Epoch 00187: val_loss did not improve from 0.63056
# Epoch 188/200
# 36200/60000 [=================>............] - ETA: 11s - loss: 0.0652 - accuracy: 1.0000Buffered data was truncated after reaching the output size limit.

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 3s 305us/step
# Test loss: 1.2589271307706833
# Test accuracy: 0.8917999863624573

# %%
model.save("fmnist_resnet20_Original_Image-model_gaussian_filter_12.h5")

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# Iterate over layers
plot_filt=0
n_pad=15
layer_counter=0
for layer in model.layers:
	  # check for convolutional layer
    if 'conv' in layer.name:
        # if filters are 3x3 or larger:
        if layer.kernel.shape[0]>=3 and layer.kernel.shape[1]>=3:
            layer_counter+=1
            list_f_response=np.zeros(layer.kernel.shape[-2]*layer.kernel.shape[-1])
            # summarize kernel shape
            print(layer_counter,layer.name,layer.kernel.shape)
            filter_counter=0
            # Iterate over every 3x3 filter in this layer
            for in_ch in range(layer.kernel.shape[-2]):
                for out_ch in range(layer.kernel.shape[-1]):
                    # pad and fft the filters
                    p_filter=layer.kernel[:,:,in_ch,out_ch]
                    filter_pad=np.pad(p_filter,pad_width=n_pad,mode='constant',constant_values=0)
                    filter_fft=np.fft.fftshift(np.abs(np.fft.fft2(filter_pad))**2)
                    filter_fft=filter_fft/np.sum(filter_fft)
                    # plot some fft examples
                    if filter_counter<plot_filt:
                        plt.imshow(filter_fft)
                        plt.colorbar()
                        plt.pause(1)
                    
                    # get x and y axis to quantify HP/LP structure
                    f_axis_0=np.arange(filter_fft.shape[0])
                    f_axis_0[f_axis_0>np.floor(filter_fft.shape[0]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[0]/2))+1)
                    f_axis_0=np.fft.fftshift(f_axis_0)
                    f_axis_1=np.arange(filter_fft.shape[1])
                    f_axis_1[f_axis_1>np.floor(filter_fft.shape[1]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[1]/2))+1)
                    f_axis_1=np.fft.fftshift(f_axis_1)

                    Y,X=np.meshgrid(f_axis_0,f_axis_1)
                    euc_dist=np.sqrt(X**2+Y**2)
                    mean_f_response=np.mean(euc_dist*filter_fft)
                    list_f_response[filter_counter]=mean_f_response

                    filter_counter+=1
            hist,bins=np.histogram(list_f_response,bins=100)
            plt.plot(hist)
            plt.savefig("fig_g12"+layer.name+".png")
            plt.pause(1)
# Out:
# 1 conv2d_1 (7, 7, 1, 64)
# 2 conv2d_2 (3, 3, 64, 64)
# 3 conv2d_3 (3, 3, 64, 64)
# 4 conv2d_4 (3, 3, 64, 64)
# 5 conv2d_5 (3, 3, 64, 64)
# 6 conv2d_6 (3, 3, 64, 128)
# 7 conv2d_7 (3, 3, 128, 128)
# 8 conv2d_9 (3, 3, 128, 128)
# 9 conv2d_10 (3, 3, 128, 128)
# 10 conv2d_11 (3, 3, 128, 256)
# 11 conv2d_12 (3, 3, 256, 256)
# 12 conv2d_14 (3, 3, 256, 256)
# 13 conv2d_15 (3, 3, 256, 256)
# 14 conv2d_16 (3, 3, 256, 512)
# 15 conv2d_17 (3, 3, 512, 512)
# 16 conv2d_19 (3, 3, 512, 512)
# 17 conv2d_20 (3, 3, 512, 512)
