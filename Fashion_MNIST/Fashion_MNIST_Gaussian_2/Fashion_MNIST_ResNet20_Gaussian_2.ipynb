# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import MaxPooling2D, AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# example of loading the fashion mnist dataset
from matplotlib import pyplot
from keras.datasets import fashion_mnist
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (X_train.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (X_test.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 8us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 4s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 2s 0us/step
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
(X_train, Y_train), (X_test, Y_test) = fashion_mnist.load_data()
from scipy.ndimage import gaussian_filter
io=[]
for i in range(60000):
  Gaussian =gaussian_filter(X_train[i], sigma=2)
  io.append(Gaussian)
io=np.array(io)
print(io.shape)
op=[]
for j in range(10000):
  Gaussian =gaussian_filter(X_test[j], sigma=2)
  op.append(Gaussian)
op=np.array(op)
print(op.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
#Summary after Gaussian filter
print('Train: X=%s, y=%s' % (io.shape, Y_train.shape))
print('Test: X=%s, y=%s' % (op.shape, Y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(io[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
#Defining constants
epochs = 200
batch_size = 100
data_augmentation = False
img_size = 28

num_classes = 10
num_filters = 64
num_blocks = 4
num_sub_blocks = 2
use_max_pool = False

# %%
x_train = io.reshape(io.shape[0],img_size,img_size,1)
x_test = op.reshape(op.shape[0],img_size,img_size,1)
input_size = (img_size, img_size,1)
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('Y_train shape:', Y_train.shape)

#Converting labels to one-hot vectors
y_train = keras.utils.to_categorical(Y_train, num_classes)
y_test = keras.utils.to_categorical(Y_test,num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Y_train shape: (60000,)

# %%
#Creating model based on ResNet published archietecture
inputs = Input(shape=input_size)
x = Conv2D(num_filters, padding='same', 
           kernel_initializer='he_normal', 
           kernel_size=7, strides=2,
           kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

#Check by applying max pooling later (setting it false as size of image is small i.e. 28x28)
if use_max_pool:
    x = MaxPooling2D(pool_size=3,padding='same', strides=2)(x)
    num_blocks =3
#Creating Conv base stack 

# Instantiate convolutional base (stack of blocks).
for i in range(num_blocks):
    for j in range(num_sub_blocks):
        strides = 1
        is_first_layer_but_not_first_block = j == 0 and i > 0
        if is_first_layer_but_not_first_block:
            strides = 2
        #Creating residual mapping using y
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   strides=strides,
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(num_filters,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal',
                   kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)
        if is_first_layer_but_not_first_block:
            x = Conv2D(num_filters,
                       kernel_size=1,
                       padding='same',
                       strides=2,
                       kernel_initializer='he_normal',
                       kernel_regularizer=l2(1e-4))(x)
        #Adding back residual mapping
        x = keras.layers.add([x, y])
        x = Activation('relu')(x)

    num_filters = 2 * num_filters

# Add classifier on top.
x = AveragePooling2D()(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                activation='softmax',
                kernel_initializer='he_normal')(y)

# Instantiate and compile model.
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 14, 14, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 14, 14, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 64)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 14, 14, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 14, 14, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 64)   36928       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 64)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 128)    73856       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 7, 7, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 7, 7, 128)    147584      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 7, 7, 128)    8320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 7, 7, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 128)    0           conv2d_8[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 7, 7, 128)    512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 128)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 7, 7, 128)    147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 7, 7, 128)    512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 128)    0           activation_7[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 256)    295168      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 256)    33024       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 256)    0           conv2d_13[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 256)    590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 256)    1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 256)    0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 256)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 512)    1180160     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 2, 2, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2, 2, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 512)    131584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 2, 2, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 512)    0           conv2d_18[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2, 2, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 2, 2, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2, 2, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 512)    2359808     activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 2, 2, 512)    2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 512)    0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2, 2, 512)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_17[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        flatten_1[0][0]
# ==================================================================================================
# Total params: 11,186,186
# Trainable params: 11,178,378
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
save_dir = os.path.join(os.getcwd(), 'saved_model')
model_name = 'fmnist_resnet_model_gaussian_filter_2.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir,model_name)
print(filepath)
# Prepare callbacks for model saving and for learning rate decaying.
checkpoint = ModelCheckpoint(filepath=filepath,
                             verbose=1,
                             save_best_only=True)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer]
# Out:
# /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5

# %%
if not data_augmentation:
    print('Using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
# Out:
# Using data augmentation.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 38s 631us/step - loss: 1.2653 - accuracy: 0.8324 - val_loss: 1.0095 - val_accuracy: 0.8532
#
# Epoch 00001: val_loss improved from inf to 1.00948, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 2/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.8311 - accuracy: 0.8780 - val_loss: 0.7710 - val_accuracy: 0.8681
#
# Epoch 00002: val_loss improved from 1.00948 to 0.77097, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 3/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.6479 - accuracy: 0.8914 - val_loss: 0.6459 - val_accuracy: 0.8797
#
# Epoch 00003: val_loss improved from 0.77097 to 0.64587, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 4/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.5505 - accuracy: 0.8979 - val_loss: 0.5844 - val_accuracy: 0.8781
#
# Epoch 00004: val_loss improved from 0.64587 to 0.58444, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 5/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.4899 - accuracy: 0.9036 - val_loss: 0.5628 - val_accuracy: 0.8756
#
# Epoch 00005: val_loss improved from 0.58444 to 0.56283, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 6/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.4512 - accuracy: 0.9074 - val_loss: 0.5081 - val_accuracy: 0.8873
#
# Epoch 00006: val_loss improved from 0.56283 to 0.50815, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 7/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.4244 - accuracy: 0.9100 - val_loss: 0.4568 - val_accuracy: 0.9009
#
# Epoch 00007: val_loss improved from 0.50815 to 0.45678, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 8/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.4017 - accuracy: 0.9132 - val_loss: 0.4623 - val_accuracy: 0.8920
#
# Epoch 00008: val_loss did not improve from 0.45678
# Epoch 9/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.3833 - accuracy: 0.9174 - val_loss: 0.4570 - val_accuracy: 0.8926
#
# Epoch 00009: val_loss did not improve from 0.45678
# Epoch 10/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.4007 - accuracy: 0.9178 - val_loss: 0.4574 - val_accuracy: 0.8975
#
# Epoch 00010: val_loss did not improve from 0.45678
# Epoch 11/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.3625 - accuracy: 0.9247 - val_loss: 0.4661 - val_accuracy: 0.8832
#
# Epoch 00011: val_loss did not improve from 0.45678
# Epoch 12/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.3768 - accuracy: 0.9263 - val_loss: 0.4478 - val_accuracy: 0.9035
#
# Epoch 00012: val_loss improved from 0.45678 to 0.44783, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 13/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.3473 - accuracy: 0.9305 - val_loss: 0.4264 - val_accuracy: 0.8991
#
# Epoch 00013: val_loss improved from 0.44783 to 0.42636, saving model to /content/saved_model/fmnist_resnet_model_gaussian_filter_2.h5
# Epoch 14/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.3368 - accuracy: 0.9329 - val_loss: 0.4616 - val_accuracy: 0.8927
#
# Epoch 00014: val_loss did not improve from 0.42636
# Epoch 15/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.3937 - accuracy: 0.9288 - val_loss: 0.4504 - val_accuracy: 0.9025
#
# Epoch 00015: val_loss did not improve from 0.42636
# Epoch 16/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.3854 - accuracy: 0.9295 - val_loss: 0.5535 - val_accuracy: 0.8905
#
# Epoch 00016: val_loss did not improve from 0.42636
# Epoch 17/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.3807 - accuracy: 0.9342 - val_loss: 0.4643 - val_accuracy: 0.8996
#
# Epoch 00017: val_loss did not improve from 0.42636
# Epoch 18/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.3200 - accuracy: 0.9452 - val_loss: 0.4520 - val_accuracy: 0.9009
#
# Epoch 00018: val_loss did not improve from 0.42636
# Epoch 19/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.2436 - accuracy: 0.9693 - val_loss: 0.4396 - val_accuracy: 0.9120
#
# Epoch 00019: val_loss did not improve from 0.42636
# Epoch 20/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.2055 - accuracy: 0.9793 - val_loss: 0.4446 - val_accuracy: 0.9134
#
# Epoch 00020: val_loss did not improve from 0.42636
# Epoch 21/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.1820 - accuracy: 0.9841 - val_loss: 0.4665 - val_accuracy: 0.9108
#
# Epoch 00021: val_loss did not improve from 0.42636
# Epoch 22/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.1698 - accuracy: 0.9857 - val_loss: 0.4636 - val_accuracy: 0.9114
#
# Epoch 00022: val_loss did not improve from 0.42636
# Epoch 23/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.1587 - accuracy: 0.9876 - val_loss: 0.5000 - val_accuracy: 0.9087
#
# Epoch 00023: val_loss did not improve from 0.42636
# Epoch 24/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.1324 - accuracy: 0.9963 - val_loss: 0.5061 - val_accuracy: 0.9144
#
# Epoch 00024: val_loss did not improve from 0.42636
# Epoch 25/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.1195 - accuracy: 0.9991 - val_loss: 0.5501 - val_accuracy: 0.9146
#
# Epoch 00025: val_loss did not improve from 0.42636
# Epoch 26/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.1131 - accuracy: 0.9992 - val_loss: 0.5691 - val_accuracy: 0.9137
#
# Epoch 00026: val_loss did not improve from 0.42636
# Epoch 27/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.1086 - accuracy: 0.9990 - val_loss: 0.5818 - val_accuracy: 0.9161
#
# Epoch 00027: val_loss did not improve from 0.42636
# Epoch 28/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.1045 - accuracy: 0.9987 - val_loss: 0.5894 - val_accuracy: 0.9120
#
# Epoch 00028: val_loss did not improve from 0.42636
# Epoch 29/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0991 - accuracy: 0.9996 - val_loss: 0.6789 - val_accuracy: 0.9148
#
# Epoch 00029: val_loss did not improve from 0.42636
# Epoch 30/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0960 - accuracy: 0.9999 - val_loss: 0.7451 - val_accuracy: 0.9166
#
# Epoch 00030: val_loss did not improve from 0.42636
# Epoch 31/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0937 - accuracy: 0.9999 - val_loss: 0.7879 - val_accuracy: 0.9141
#
# Epoch 00031: val_loss did not improve from 0.42636
# Epoch 32/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0919 - accuracy: 0.9998 - val_loss: 0.7365 - val_accuracy: 0.9149
#
# Epoch 00032: val_loss did not improve from 0.42636
# Epoch 33/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0892 - accuracy: 1.0000 - val_loss: 0.8411 - val_accuracy: 0.9158
#
# Epoch 00033: val_loss did not improve from 0.42636
# Epoch 34/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 0.8849 - val_accuracy: 0.9152
#
# Epoch 00034: val_loss did not improve from 0.42636
# Epoch 35/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0864 - accuracy: 1.0000 - val_loss: 0.9082 - val_accuracy: 0.9150
#
# Epoch 00035: val_loss did not improve from 0.42636
# Epoch 36/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0852 - accuracy: 1.0000 - val_loss: 0.9179 - val_accuracy: 0.9153
#
# Epoch 00036: val_loss did not improve from 0.42636
# Epoch 37/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0840 - accuracy: 1.0000 - val_loss: 0.8390 - val_accuracy: 0.9149
#
# Epoch 00037: val_loss did not improve from 0.42636
# Epoch 38/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 0.8675 - val_accuracy: 0.9155
#
# Epoch 00038: val_loss did not improve from 0.42636
# Epoch 39/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 0.8831 - val_accuracy: 0.9156
#
# Epoch 00039: val_loss did not improve from 0.42636
# Epoch 40/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0809 - accuracy: 1.0000 - val_loss: 0.8993 - val_accuracy: 0.9156
#
# Epoch 00040: val_loss did not improve from 0.42636
# Epoch 41/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0802 - accuracy: 1.0000 - val_loss: 0.8997 - val_accuracy: 0.9146
#
# Epoch 00041: val_loss did not improve from 0.42636
# Epoch 42/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0796 - accuracy: 1.0000 - val_loss: 0.9079 - val_accuracy: 0.9149
#
# Epoch 00042: val_loss did not improve from 0.42636
# Epoch 43/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0789 - accuracy: 1.0000 - val_loss: 0.9057 - val_accuracy: 0.9152
#
# Epoch 00043: val_loss did not improve from 0.42636
# Epoch 44/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0785 - accuracy: 1.0000 - val_loss: 0.9113 - val_accuracy: 0.9153
#
# Epoch 00044: val_loss did not improve from 0.42636
# Epoch 45/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0783 - accuracy: 1.0000 - val_loss: 0.9085 - val_accuracy: 0.9152
#
# Epoch 00045: val_loss did not improve from 0.42636
# Epoch 46/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0780 - accuracy: 1.0000 - val_loss: 0.9095 - val_accuracy: 0.9158
#
# Epoch 00046: val_loss did not improve from 0.42636
# Epoch 47/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0777 - accuracy: 1.0000 - val_loss: 0.9085 - val_accuracy: 0.9158
#
# Epoch 00047: val_loss did not improve from 0.42636
# Epoch 48/200
# 60000/60000 [==============================] - 27s 456us/step - loss: 0.0773 - accuracy: 1.0000 - val_loss: 0.9156 - val_accuracy: 0.9158
#
# Epoch 00048: val_loss did not improve from 0.42636
# Epoch 49/200
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.0769 - accuracy: 1.0000 - val_loss: 0.9170 - val_accuracy: 0.9156
#
# Epoch 00049: val_loss did not improve from 0.42636
# Epoch 50/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 0.9152 - val_accuracy: 0.9152
#
# Epoch 00050: val_loss did not improve from 0.42636
# Epoch 51/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0764 - accuracy: 1.0000 - val_loss: 0.9199 - val_accuracy: 0.9151
#
# Epoch 00051: val_loss did not improve from 0.42636
# Epoch 52/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 0.9186 - val_accuracy: 0.9157
#
# Epoch 00052: val_loss did not improve from 0.42636
# Epoch 53/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.9219 - val_accuracy: 0.9155
#
# Epoch 00053: val_loss did not improve from 0.42636
# Epoch 54/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 0.9195 - val_accuracy: 0.9156
#
# Epoch 00054: val_loss did not improve from 0.42636
# Epoch 55/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 0.9195 - val_accuracy: 0.9161
#
# Epoch 00055: val_loss did not improve from 0.42636
# Epoch 56/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 0.9251 - val_accuracy: 0.9154
#
# Epoch 00056: val_loss did not improve from 0.42636
# Epoch 57/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0748 - accuracy: 1.0000 - val_loss: 0.9259 - val_accuracy: 0.9151
#
# Epoch 00057: val_loss did not improve from 0.42636
# Epoch 58/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.9279 - val_accuracy: 0.9152
#
# Epoch 00058: val_loss did not improve from 0.42636
# Epoch 59/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0744 - accuracy: 1.0000 - val_loss: 0.9249 - val_accuracy: 0.9148
#
# Epoch 00059: val_loss did not improve from 0.42636
# Epoch 60/200
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 0.9283 - val_accuracy: 0.9148
#
# Epoch 00060: val_loss did not improve from 0.42636
# Epoch 61/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.9324 - val_accuracy: 0.9148
#
# Epoch 00061: val_loss did not improve from 0.42636
# Epoch 62/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0736 - accuracy: 1.0000 - val_loss: 0.9306 - val_accuracy: 0.9155
#
# Epoch 00062: val_loss did not improve from 0.42636
# Epoch 63/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.9360 - val_accuracy: 0.9153
#
# Epoch 00063: val_loss did not improve from 0.42636
# Epoch 64/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0732 - accuracy: 1.0000 - val_loss: 0.9349 - val_accuracy: 0.9158
#
# Epoch 00064: val_loss did not improve from 0.42636
# Epoch 65/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.9345 - val_accuracy: 0.9154
#
# Epoch 00065: val_loss did not improve from 0.42636
# Epoch 66/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 0.9333 - val_accuracy: 0.9154
#
# Epoch 00066: val_loss did not improve from 0.42636
# Epoch 67/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.9381 - val_accuracy: 0.9157
#
# Epoch 00067: val_loss did not improve from 0.42636
# Epoch 68/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0724 - accuracy: 1.0000 - val_loss: 0.9364 - val_accuracy: 0.9152
#
# Epoch 00068: val_loss did not improve from 0.42636
# Epoch 69/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0722 - accuracy: 1.0000 - val_loss: 0.9392 - val_accuracy: 0.9153
#
# Epoch 00069: val_loss did not improve from 0.42636
# Epoch 70/200
# 60000/60000 [==============================] - 28s 458us/step - loss: 0.0720 - accuracy: 1.0000 - val_loss: 0.9383 - val_accuracy: 0.9153
#
# Epoch 00070: val_loss did not improve from 0.42636
# Epoch 71/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0718 - accuracy: 1.0000 - val_loss: 0.9396 - val_accuracy: 0.9151
#
# Epoch 00071: val_loss did not improve from 0.42636
# Epoch 72/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 0.9400 - val_accuracy: 0.9155
#
# Epoch 00072: val_loss did not improve from 0.42636
# Epoch 73/200
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.9382 - val_accuracy: 0.9155
#
# Epoch 00073: val_loss did not improve from 0.42636
# Epoch 74/200
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 0.9371 - val_accuracy: 0.9150
#
# Epoch 00074: val_loss did not improve from 0.42636
# Epoch 75/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 0.9413 - val_accuracy: 0.9149
#
# Epoch 00075: val_loss did not improve from 0.42636
# Epoch 76/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0709 - accuracy: 1.0000 - val_loss: 0.9414 - val_accuracy: 0.9148
#
# Epoch 00076: val_loss did not improve from 0.42636
# Epoch 77/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0707 - accuracy: 1.0000 - val_loss: 0.9441 - val_accuracy: 0.9150
#
# Epoch 00077: val_loss did not improve from 0.42636
# Epoch 78/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.9390 - val_accuracy: 0.9155
#
# Epoch 00078: val_loss did not improve from 0.42636
# Epoch 79/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0703 - accuracy: 1.0000 - val_loss: 0.9428 - val_accuracy: 0.9150
#
# Epoch 00079: val_loss did not improve from 0.42636
# Epoch 80/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.9454 - val_accuracy: 0.9154
#
# Epoch 00080: val_loss did not improve from 0.42636
# Epoch 81/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.9424 - val_accuracy: 0.9151
#
# Epoch 00081: val_loss did not improve from 0.42636
# Epoch 82/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.9465 - val_accuracy: 0.9155
#
# Epoch 00082: val_loss did not improve from 0.42636
# Epoch 83/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 0.9478 - val_accuracy: 0.9152
#
# Epoch 00083: val_loss did not improve from 0.42636
# Epoch 84/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.9520 - val_accuracy: 0.9153
#
# Epoch 00084: val_loss did not improve from 0.42636
# Epoch 85/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 0.9578 - val_accuracy: 0.9152
#
# Epoch 00085: val_loss did not improve from 0.42636
# Epoch 86/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.9537 - val_accuracy: 0.9155
#
# Epoch 00086: val_loss did not improve from 0.42636
# Epoch 87/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 0.9513 - val_accuracy: 0.9152
#
# Epoch 00087: val_loss did not improve from 0.42636
# Epoch 88/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 0.9518 - val_accuracy: 0.9161
#
# Epoch 00088: val_loss did not improve from 0.42636
# Epoch 89/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0682 - accuracy: 1.0000 - val_loss: 0.9519 - val_accuracy: 0.9158
#
# Epoch 00089: val_loss did not improve from 0.42636
# Epoch 90/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 0.9541 - val_accuracy: 0.9157
#
# Epoch 00090: val_loss did not improve from 0.42636
# Epoch 91/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.9538 - val_accuracy: 0.9159
#
# Epoch 00091: val_loss did not improve from 0.42636
# Epoch 92/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.9515 - val_accuracy: 0.9156
#
# Epoch 00092: val_loss did not improve from 0.42636
# Epoch 93/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.9494 - val_accuracy: 0.9157
#
# Epoch 00093: val_loss did not improve from 0.42636
# Epoch 94/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.9507 - val_accuracy: 0.9160
#
# Epoch 00094: val_loss did not improve from 0.42636
# Epoch 95/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.9554 - val_accuracy: 0.9158
#
# Epoch 00095: val_loss did not improve from 0.42636
# Epoch 96/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.9588 - val_accuracy: 0.9153
#
# Epoch 00096: val_loss did not improve from 0.42636
# Epoch 97/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.9578 - val_accuracy: 0.9160
#
# Epoch 00097: val_loss did not improve from 0.42636
# Epoch 98/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 0.9504 - val_accuracy: 0.9158
#
# Epoch 00098: val_loss did not improve from 0.42636
# Epoch 99/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.9531 - val_accuracy: 0.9160
#
# Epoch 00099: val_loss did not improve from 0.42636
# Epoch 100/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.9524 - val_accuracy: 0.9153
#
# Epoch 00100: val_loss did not improve from 0.42636
# Epoch 101/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0653 - accuracy: 1.0000 - val_loss: 0.9524 - val_accuracy: 0.9151
#
# Epoch 00101: val_loss did not improve from 0.42636
# Epoch 102/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.9554 - val_accuracy: 0.9159
#
# Epoch 00102: val_loss did not improve from 0.42636
# Epoch 103/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.9523 - val_accuracy: 0.9153
#
# Epoch 00103: val_loss did not improve from 0.42636
# Epoch 104/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.9532 - val_accuracy: 0.9160
#
# Epoch 00104: val_loss did not improve from 0.42636
# Epoch 105/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0645 - accuracy: 1.0000 - val_loss: 0.9531 - val_accuracy: 0.9153
#
# Epoch 00105: val_loss did not improve from 0.42636
# Epoch 106/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0643 - accuracy: 1.0000 - val_loss: 0.9538 - val_accuracy: 0.9159
#
# Epoch 00106: val_loss did not improve from 0.42636
# Epoch 107/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0640 - accuracy: 1.0000 - val_loss: 0.9548 - val_accuracy: 0.9156
#
# Epoch 00107: val_loss did not improve from 0.42636
# Epoch 108/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0638 - accuracy: 1.0000 - val_loss: 0.9530 - val_accuracy: 0.9151
#
# Epoch 00108: val_loss did not improve from 0.42636
# Epoch 109/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.9531 - val_accuracy: 0.9155
#
# Epoch 00109: val_loss did not improve from 0.42636
# Epoch 110/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 0.9527 - val_accuracy: 0.9157
#
# Epoch 00110: val_loss did not improve from 0.42636
# Epoch 111/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.9482 - val_accuracy: 0.9156
#
# Epoch 00111: val_loss did not improve from 0.42636
# Epoch 112/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 0.9525 - val_accuracy: 0.9154
#
# Epoch 00112: val_loss did not improve from 0.42636
# Epoch 113/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 0.9553 - val_accuracy: 0.9149
#
# Epoch 00113: val_loss did not improve from 0.42636
# Epoch 114/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0624 - accuracy: 1.0000 - val_loss: 0.9515 - val_accuracy: 0.9155
#
# Epoch 00114: val_loss did not improve from 0.42636
# Epoch 115/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.9566 - val_accuracy: 0.9155
#
# Epoch 00115: val_loss did not improve from 0.42636
# Epoch 116/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 0.9568 - val_accuracy: 0.9148
#
# Epoch 00116: val_loss did not improve from 0.42636
# Epoch 117/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.9514 - val_accuracy: 0.9151
#
# Epoch 00117: val_loss did not improve from 0.42636
# Epoch 118/200
# 60000/60000 [==============================] - 28s 458us/step - loss: 0.0619 - accuracy: 1.0000 - val_loss: 0.9534 - val_accuracy: 0.9156
#
# Epoch 00118: val_loss did not improve from 0.42636
# Epoch 119/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0618 - accuracy: 1.0000 - val_loss: 0.9497 - val_accuracy: 0.9151
#
# Epoch 00119: val_loss did not improve from 0.42636
# Epoch 120/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.9542 - val_accuracy: 0.9149
#
# Epoch 00120: val_loss did not improve from 0.42636
# Epoch 121/200
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.0615 - accuracy: 1.0000 - val_loss: 0.9560 - val_accuracy: 0.9143
#
# Epoch 00121: val_loss did not improve from 0.42636
# Epoch 122/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.9148
#
# Epoch 00122: val_loss did not improve from 0.42636
# Epoch 123/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.9535 - val_accuracy: 0.9148
#
# Epoch 00123: val_loss did not improve from 0.42636
# Epoch 124/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.9513 - val_accuracy: 0.9151
#
# Epoch 00124: val_loss did not improve from 0.42636
# Epoch 125/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0606 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.9152
#
# Epoch 00125: val_loss did not improve from 0.42636
# Epoch 126/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0604 - accuracy: 1.0000 - val_loss: 0.9557 - val_accuracy: 0.9148
#
# Epoch 00126: val_loss did not improve from 0.42636
# Epoch 127/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0602 - accuracy: 1.0000 - val_loss: 0.9568 - val_accuracy: 0.9151
#
# Epoch 00127: val_loss did not improve from 0.42636
# Epoch 128/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 0.9497 - val_accuracy: 0.9156
#
# Epoch 00128: val_loss did not improve from 0.42636
# Epoch 129/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.9511 - val_accuracy: 0.9149
#
# Epoch 00129: val_loss did not improve from 0.42636
# Epoch 130/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0596 - accuracy: 1.0000 - val_loss: 0.9519 - val_accuracy: 0.9152
#
# Epoch 00130: val_loss did not improve from 0.42636
# Epoch 131/200
# 60000/60000 [==============================] - 28s 458us/step - loss: 0.0593 - accuracy: 1.0000 - val_loss: 0.9507 - val_accuracy: 0.9148
#
# Epoch 00131: val_loss did not improve from 0.42636
# Epoch 132/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.9516 - val_accuracy: 0.9151
#
# Epoch 00132: val_loss did not improve from 0.42636
# Epoch 133/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 0.9553 - val_accuracy: 0.9151
#
# Epoch 00133: val_loss did not improve from 0.42636
# Epoch 134/200
# 60000/60000 [==============================] - 27s 457us/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.9548 - val_accuracy: 0.9149
#
# Epoch 00134: val_loss did not improve from 0.42636
# Epoch 135/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.9535 - val_accuracy: 0.9151
#
# Epoch 00135: val_loss did not improve from 0.42636
# Epoch 136/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.9558 - val_accuracy: 0.9151
#
# Epoch 00136: val_loss did not improve from 0.42636
# Epoch 137/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.9538 - val_accuracy: 0.9149
#
# Epoch 00137: val_loss did not improve from 0.42636
# Epoch 138/200
# 60000/60000 [==============================] - 27s 458us/step - loss: 0.0575 - accuracy: 1.0000 - val_loss: 0.9549 - val_accuracy: 0.9147
#
# Epoch 00138: val_loss did not improve from 0.42636
# Epoch 139/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0574 - accuracy: 1.0000 - val_loss: 0.9515 - val_accuracy: 0.9150
#
# Epoch 00139: val_loss did not improve from 0.42636
# Epoch 140/200
# 60000/60000 [==============================] - 28s 458us/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.9522 - val_accuracy: 0.9152
#
# Epoch 00140: val_loss did not improve from 0.42636
# Epoch 141/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.9530 - val_accuracy: 0.9144
#
# Epoch 00141: val_loss did not improve from 0.42636
# Epoch 142/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0568 - accuracy: 1.0000 - val_loss: 0.9521 - val_accuracy: 0.9155
#
# Epoch 00142: val_loss did not improve from 0.42636
# Epoch 143/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.9536 - val_accuracy: 0.9151
#
# Epoch 00143: val_loss did not improve from 0.42636
# Epoch 144/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0564 - accuracy: 1.0000 - val_loss: 0.9528 - val_accuracy: 0.9146
#
# Epoch 00144: val_loss did not improve from 0.42636
# Epoch 145/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0563 - accuracy: 1.0000 - val_loss: 0.9556 - val_accuracy: 0.9151
#
# Epoch 00145: val_loss did not improve from 0.42636
# Epoch 146/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0562 - accuracy: 1.0000 - val_loss: 0.9545 - val_accuracy: 0.9148
#
# Epoch 00146: val_loss did not improve from 0.42636
# Epoch 147/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 0.9509 - val_accuracy: 0.9154
#
# Epoch 00147: val_loss did not improve from 0.42636
# Epoch 148/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.9512 - val_accuracy: 0.9154
#
# Epoch 00148: val_loss did not improve from 0.42636
# Epoch 149/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.9501 - val_accuracy: 0.9145
#
# Epoch 00149: val_loss did not improve from 0.42636
# Epoch 150/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.9500 - val_accuracy: 0.9149
#
# Epoch 00150: val_loss did not improve from 0.42636
# Epoch 151/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.9502 - val_accuracy: 0.9155
#
# Epoch 00151: val_loss did not improve from 0.42636
# Epoch 152/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 0.9477 - val_accuracy: 0.9153
#
# Epoch 00152: val_loss did not improve from 0.42636
# Epoch 153/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0552 - accuracy: 1.0000 - val_loss: 0.9532 - val_accuracy: 0.9153
#
# Epoch 00153: val_loss did not improve from 0.42636
# Epoch 154/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0551 - accuracy: 1.0000 - val_loss: 0.9551 - val_accuracy: 0.9148
#
# Epoch 00154: val_loss did not improve from 0.42636
# Epoch 155/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.9589 - val_accuracy: 0.9153
#
# Epoch 00155: val_loss did not improve from 0.42636
# Epoch 156/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.9554 - val_accuracy: 0.9152
#
# Epoch 00156: val_loss did not improve from 0.42636
# Epoch 157/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.9149
#
# Epoch 00157: val_loss did not improve from 0.42636
# Epoch 158/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.9517 - val_accuracy: 0.9158
#
# Epoch 00158: val_loss did not improve from 0.42636
# Epoch 159/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.9526 - val_accuracy: 0.9155
#
# Epoch 00159: val_loss did not improve from 0.42636
# Epoch 160/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.9512 - val_accuracy: 0.9142
#
# Epoch 00160: val_loss did not improve from 0.42636
# Epoch 161/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.9513 - val_accuracy: 0.9159
#
# Epoch 00161: val_loss did not improve from 0.42636
# Epoch 162/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.9528 - val_accuracy: 0.9160
#
# Epoch 00162: val_loss did not improve from 0.42636
# Epoch 163/200
# 60000/60000 [==============================] - 28s 462us/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.9531 - val_accuracy: 0.9163
#
# Epoch 00163: val_loss did not improve from 0.42636
# Epoch 164/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.9520 - val_accuracy: 0.9151
#
# Epoch 00164: val_loss did not improve from 0.42636
# Epoch 165/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.9481 - val_accuracy: 0.9156
#
# Epoch 00165: val_loss did not improve from 0.42636
# Epoch 166/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.9484 - val_accuracy: 0.9155
#
# Epoch 00166: val_loss did not improve from 0.42636
# Epoch 167/200
# 60000/60000 [==============================] - 28s 460us/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.9486 - val_accuracy: 0.9154
#
# Epoch 00167: val_loss did not improve from 0.42636
# Epoch 168/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.9504 - val_accuracy: 0.9153
#
# Epoch 00168: val_loss did not improve from 0.42636
# Epoch 169/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.9478 - val_accuracy: 0.9149
#
# Epoch 00169: val_loss did not improve from 0.42636
# Epoch 170/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.9502 - val_accuracy: 0.9150
#
# Epoch 00170: val_loss did not improve from 0.42636
# Epoch 171/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.9464 - val_accuracy: 0.9152
#
# Epoch 00171: val_loss did not improve from 0.42636
# Epoch 172/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.9486 - val_accuracy: 0.9152
#
# Epoch 00172: val_loss did not improve from 0.42636
# Epoch 173/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.9456 - val_accuracy: 0.9152
#
# Epoch 00173: val_loss did not improve from 0.42636
# Epoch 174/200
# 60000/60000 [==============================] - 28s 461us/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.9435 - val_accuracy: 0.9151
#
# Epoch 00174: val_loss did not improve from 0.42636
# Epoch 175/200
# 60000/60000 [==============================] - 28s 459us/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.9442 - val_accuracy: 0.9154
#
# Epoch 00175: val_loss did not improve from 0.42636
# Epoch 176/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.9451 - val_accuracy: 0.9153
#
# Epoch 00176: val_loss did not improve from 0.42636
# Epoch 177/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.9465 - val_accuracy: 0.9161
#
# Epoch 00177: val_loss did not improve from 0.42636
# Epoch 178/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.9471 - val_accuracy: 0.9155
#
# Epoch 00178: val_loss did not improve from 0.42636
# Epoch 179/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.9475 - val_accuracy: 0.9164
#
# Epoch 00179: val_loss did not improve from 0.42636
# Epoch 180/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.9469 - val_accuracy: 0.9154
#
# Epoch 00180: val_loss did not improve from 0.42636
# Epoch 181/200
# 60000/60000 [==============================] - 28s 466us/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.9465 - val_accuracy: 0.9148
#
# Epoch 00181: val_loss did not improve from 0.42636
# Epoch 182/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.9441 - val_accuracy: 0.9159
#
# Epoch 00182: val_loss did not improve from 0.42636
# Epoch 183/200
# 60000/60000 [==============================] - 28s 463us/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.9426 - val_accuracy: 0.9161
#
# Epoch 00183: val_loss did not improve from 0.42636
# Epoch 184/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.9415 - val_accuracy: 0.9159
#
# Epoch 00184: val_loss did not improve from 0.42636
# Epoch 185/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.9415 - val_accuracy: 0.9160
#
# Epoch 00185: val_loss did not improve from 0.42636
# Epoch 186/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.9391 - val_accuracy: 0.9151
#
# Epoch 00186: val_loss did not improve from 0.42636
# Epoch 187/200
# 60000/60000 [==============================] - 28s 464us/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.9399 - val_accuracy: 0.9159
#
# Epoch 00187: val_loss did not improve from 0.42636
# Epoch 188/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.9421 - val_accuracy: 0.9148
#
# Epoch 00188: val_loss did not improve from 0.42636
# Epoch 189/200
# 60000/60000 [==============================] - 28s 465us/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.9389 - val_accuracy: 0.9160
#
# Epoch 00189: val_loss did not improve from 0.42636
# Epoch 190/200
# 60000/60000 [==============================] - 28s 467us/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.9440 - val_accuracy: 0.9154
#
# Epoch 00190: val_loss did not improve from 0.42636
# Epoch 191/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0499 - accuracy: 1.0000 - val_loss: 0.9441 - val_accuracy: 0.9155
#
# Epoch 00191: val_loss did not improve from 0.42636
# Epoch 192/200
# 60000/60000 [==============================] - 28s 471us/step - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.9451 - val_accuracy: 0.9155
#
# Epoch 00192: val_loss did not improve from 0.42636
# Epoch 193/200
# 60000/60000 [==============================] - 28s 472us/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.9450 - val_accuracy: 0.9147
#
# Epoch 00193: val_loss did not improve from 0.42636
# Epoch 194/200
# 60000/60000 [==============================] - 29s 480us/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.9405 - val_accuracy: 0.9151
#
# Epoch 00194: val_loss did not improve from 0.42636
# Epoch 195/200
# 60000/60000 [==============================] - 29s 481us/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.9399 - val_accuracy: 0.9155
#
# Epoch 00195: val_loss did not improve from 0.42636
# Epoch 196/200
# 60000/60000 [==============================] - 28s 472us/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.9396 - val_accuracy: 0.9147
#
# Epoch 00196: val_loss did not improve from 0.42636
# Epoch 197/200
# 60000/60000 [==============================] - 28s 472us/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.9416 - val_accuracy: 0.9152
#
# Epoch 00197: val_loss did not improve from 0.42636
# Epoch 198/200
# 60000/60000 [==============================] - 28s 472us/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 0.9417 - val_accuracy: 0.9152
#
# Epoch 00198: val_loss did not improve from 0.42636
# Epoch 199/200
# 60000/60000 [==============================] - 28s 469us/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.9392 - val_accuracy: 0.9155
#
# Epoch 00199: val_loss did not improve from 0.42636
# Epoch 200/200
# 60000/60000 [==============================] - 28s 468us/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.9363 - val_accuracy: 0.9154
#
# Epoch 00200: val_loss did not improve from 0.42636

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 3s 295us/step
# Test loss: 0.9363077579975129
# Test accuracy: 0.9154000282287598

# %%
model.save("ResNet18_Fashion_MNIST_Gaussian_Filter2.h5")

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
# Iterate over layers
plot_filt=0
n_pad=15
layer_counter=0
for layer in model.layers:
	  # check for convolutional layer
    if 'conv' in layer.name:
        # if filters are 3x3 or larger:
        if layer.kernel.shape[0]>=3 and layer.kernel.shape[1]>=3:
            layer_counter+=1
            list_f_response=np.zeros(layer.kernel.shape[-2]*layer.kernel.shape[-1])
            # summarize kernel shape
            print(layer_counter,layer.name,layer.kernel.shape)
            filter_counter=0
            # Iterate over every 3x3 filter in this layer
            for in_ch in range(layer.kernel.shape[-2]):
                for out_ch in range(layer.kernel.shape[-1]):
                    # pad and fft the filters
                    p_filter=layer.kernel[:,:,in_ch,out_ch]
                    filter_pad=np.pad(p_filter,pad_width=n_pad,mode='constant',constant_values=0)
                    filter_fft=np.fft.fftshift(np.abs(np.fft.fft2(filter_pad))**2)
                    filter_fft=filter_fft/np.sum(filter_fft)
                    # plot some fft examples
                    if filter_counter<plot_filt:
                        plt.imshow(filter_fft)
                        plt.colorbar()
                        plt.pause(1)
                    
                    # get x and y axis to quantify HP/LP structure
                    f_axis_0=np.arange(filter_fft.shape[0])
                    f_axis_0[f_axis_0>np.floor(filter_fft.shape[0]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[0]/2))+1)
                    f_axis_0=np.fft.fftshift(f_axis_0)
                    f_axis_1=np.arange(filter_fft.shape[1])
                    f_axis_1[f_axis_1>np.floor(filter_fft.shape[1]/2)]=np.flip(np.arange(np.floor(filter_fft.shape[1]/2))+1)
                    f_axis_1=np.fft.fftshift(f_axis_1)

                    Y,X=np.meshgrid(f_axis_0,f_axis_1)
                    euc_dist=np.sqrt(X**2+Y**2)
                    mean_f_response=np.mean(euc_dist*filter_fft)
                    list_f_response[filter_counter]=mean_f_response

                    filter_counter+=1
            hist,bins=np.histogram(list_f_response,bins=100)
            plt.plot(hist)
            plt.savefig("fig_g2"+layer.name+".png")
            plt.pause(1)
# Out:
# 1 conv2d_1 (7, 7, 1, 64)
# 2 conv2d_2 (3, 3, 64, 64)
# 3 conv2d_3 (3, 3, 64, 64)
# 4 conv2d_4 (3, 3, 64, 64)
# 5 conv2d_5 (3, 3, 64, 64)
# 6 conv2d_6 (3, 3, 64, 128)
# 7 conv2d_7 (3, 3, 128, 128)
# 8 conv2d_9 (3, 3, 128, 128)
# 9 conv2d_10 (3, 3, 128, 128)
# 10 conv2d_11 (3, 3, 128, 256)
# 11 conv2d_12 (3, 3, 256, 256)
# 12 conv2d_14 (3, 3, 256, 256)
# 13 conv2d_15 (3, 3, 256, 256)
# 14 conv2d_16 (3, 3, 256, 512)
# 15 conv2d_17 (3, 3, 512, 512)
# 16 conv2d_19 (3, 3, 512, 512)
# 17 conv2d_20 (3, 3, 512, 512)
